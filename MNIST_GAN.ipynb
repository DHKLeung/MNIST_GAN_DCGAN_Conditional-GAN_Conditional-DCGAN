# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import imageio
from tensorflow.examples.tutorials.mnist import input_data
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
"""
Compute the time elapsed
"""
def tic():
    global tic_time
    tic_time = time.time()
    
def toc():
    return time.time() - tic_time

# %%
"""
Load MNIST data
Return: all 70000(train + val + test) images
"""
def load_data():
    mnist = input_data.read_data_sets('MNIST_data/')
    images = np.append(np.append(mnist.train.images, mnist.validation.images, axis=0), mnist.test.images, axis=0)
    return images

# %%
"""
Define the Generator
"""
def generator(noises_input, n_1, n_2, n_3, n_out):
    with tf.variable_scope('generator'):
        Z1 = tf.contrib.layers.fully_connected(noises_input, n_1, activation_fn=None, scope='Z1')
        A1 = tf.nn.leaky_relu(Z1, name='A1')
        Z2 = tf.contrib.layers.fully_connected(A1, n_2, activation_fn=None, scope='Z2')
        A2 = tf.nn.leaky_relu(Z2, name='A2')
        Z3 = tf.contrib.layers.fully_connected(A2, n_3, activation_fn=None, scope='Z3')
        A3 = tf.nn.leaky_relu(Z3, name='A3')
        Z_out = tf.contrib.layers.fully_connected(A3, n_out, activation_fn=None, scope='Z_out')
        A_out = tf.nn.tanh(Z_out, name='A_out')
    return A_out

# %%
"""
Define the Discriminator
"""
def discriminator(images_input, n_1, n_2, n_3, n_out, reuse=False):
    with tf.variable_scope('discriminator', reuse=reuse):
        Z1 = tf.contrib.layers.fully_connected(images_input, n_1, activation_fn=None, scope='Z1')
        A1 = tf.nn.leaky_relu(Z1, name='A1')
        A1_dropout = tf.nn.dropout(A1, 0.7, name='A1_dropout')
        Z2 = tf.contrib.layers.fully_connected(A1_dropout, n_2, activation_fn=None, scope='Z2')
        A2 = tf.nn.leaky_relu(Z2, name='A2')
        A2_dropout = tf.nn.dropout(A2, 0.7, name='A2_dropout')
        Z3 = tf.contrib.layers.fully_connected(A2_dropout, n_3, activation_fn=None, scope='Z3')
        A3 = tf.nn.leaky_relu(Z3, name='A3')
        A3_dropout = tf.nn.dropout(A3, 0.7, name='A3_dropout')
        Z_out = tf.contrib.layers.fully_connected(A3_dropout, n_out, activation_fn=None, scope='Z_out')
    return Z_out

# %%
"""
Define and Train Generative Adversarial Networks(GANs) Model
Return: history of costs(both generator and discriminator) 
        samples generated in each epoch
"""
def MNIST_GAN(hyperparams):
    tf.reset_default_graph()
    mnist_images = load_data() * 2 - 1
    noise_size = hyperparams['noise_size']
    batch_size = hyperparams['batch_size']
    epoch = hyperparams['epoch']
    generator_n_1 = hyperparams['generator_n_1']
    generator_n_2 = hyperparams['generator_n_2']
    generator_n_3 = hyperparams['generator_n_3']
    generator_n_out = hyperparams['generator_n_out']
    discriminator_n_1 = hyperparams['discriminator_n_1']
    discriminator_n_2 = hyperparams['discriminator_n_2']
    discriminator_n_3 = hyperparams['discriminator_n_3']
    discriminator_n_out = hyperparams['discriminator_n_out']
    learning_rate = hyperparams['learning_rate']
    sample_size = hyperparams['sample_size']
    data_size = mnist_images.shape[0]
    image_size = mnist_images.shape[1]
    total_batches = np.ceil(data_size / batch_size).astype(np.int32)
    real_images = tf.placeholder(tf.float32, (None, image_size), name='real_images')
    noises_input = tf.placeholder(tf.float32, (None, noise_size), name='noises_input')
    fake_images = generator(noises_input, generator_n_1, generator_n_2, generator_n_3, generator_n_out)
    real_logits = discriminator(real_images, discriminator_n_1, discriminator_n_2, discriminator_n_3, discriminator_n_out)
    fake_logits = discriminator(fake_images, discriminator_n_1, discriminator_n_2, discriminator_n_3, discriminator_n_out, reuse=True)
    dis_real_cost = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=real_logits, labels=tf.ones_like(real_logits)))
    dis_fake_cost = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logits, labels=tf.zeros_like(fake_logits)))
    dis_cost = tf.divide(tf.add(dis_real_cost, dis_fake_cost), 2)
    gen_cost = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logits, labels=tf.ones_like(fake_logits)))
    trainable_vars = tf.trainable_variables()
    gen_vars = [var for var in trainable_vars if var.name.startswith('generator')]
    dis_vars = [var for var in trainable_vars if var.name.startswith('discriminator')]
    gen_optimize = tf.train.RMSPropOptimizer(learning_rate=learning_rate, name='gen_optimize').minimize(gen_cost, var_list=gen_vars)
    dis_optimize = tf.train.RMSPropOptimizer(learning_rate=learning_rate, name='dis_optimize').minimize(dis_cost, var_list=dis_vars)
    costs_history = []
    sample_images_generated = np.empty((0, sample_size, image_size))
    sample_noises_input = np.random.uniform(low=-1, high=1, size=(sample_size, noise_size))
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(epoch):
            tic()
            noises = np.empty((0, noise_size))
            for j in range(total_batches):
                index_front = j * batch_size
                index_end = (j + 1) * batch_size if (j + 1) * batch_size < data_size else data_size
                images_batch = mnist_images[index_front:index_end].reshape(-1, image_size)
                noises_batch = np.random.uniform(low=-1, high=1, size=(index_end - index_front, noise_size))
                sess.run(dis_optimize, feed_dict={real_images:images_batch, noises_input:noises_batch})
                sess.run(gen_optimize, feed_dict={noises_input:noises_batch})
                noises = np.append(noises, noises_batch, axis=0)
            dis_epoch_cost_real, dis_epoch_cost_fake, dis_epoch_cost, gen_epoch_cost = sess.run([dis_real_cost, dis_fake_cost, dis_cost, gen_cost], feed_dict={real_images:mnist_images, noises_input:noises})
            costs_history.append((dis_epoch_cost_real, dis_epoch_cost_fake, dis_epoch_cost, gen_epoch_cost))
            sample_images_generated_epoch = sess.run(fake_images, feed_dict={noises_input:sample_noises_input}).reshape(1, -1, image_size)
            sample_images_generated = np.append(sample_images_generated, sample_images_generated_epoch, axis=0)
            print('Epoch {}/{} Time Elapsed: {:.2f}s'.format(i + 1, epoch, toc()))
            print('Discriminator Cost: {:.4f} (Real: {:.4f} + Fake: {:.4f}) Generator Cost: {:.4f}'.format(dis_epoch_cost, dis_epoch_cost_real, dis_epoch_cost_fake, gen_epoch_cost))
        return costs_history, sample_images_generated

# %%
"""
Show graphs of costs of discriminator and generator
"""
def show_graphs(costs_history):
    costs = np.array(costs_history).T
    plt.figure(figsize=(20, 10))
    plt.ylabel('Cost')
    plt.xlabel('Epoch')
    plt.title('Cost - Epoch')
    plt.plot(costs[0], label='Discriminator Real Cost')
    plt.plot(costs[1], label='Discriminator Fake Cost')
    plt.plot(costs[2], label='Discriminator Total Cost')
    plt.plot(costs[3], label='Generator Cost')
    plt.legend(loc='best')
    plt.show()

# %%
"""
Show and save samples
Variables: 
    sample_images_generated shape: (num of epochs, num of samples in each epoch, num of rows of image, num of column of image)
    save: True if want to save the figures(pngs and gifs)
    folder_name: create the folder if not exists, save figures to the specific folder
"""
def show_save_samples(sample_images_generated, save=False, folder_name='MNIST_GAN_samples', gif_frame_duration=0.25):
    sample_images_generated = (sample_images_generated + 1) / 2
    if save and not os.path.exists('./{}'.format(folder_name)):
        os.mkdir(folder_name)
    epochs = sample_images_generated.shape[0]
    num_sample_each_epoch = sample_images_generated.shape[1]
    for i in range(epochs):
        plt.figure(figsize=(2 * num_sample_each_epoch, 5))
        for j in range(num_sample_each_epoch):
            plt.subplot(1, num_sample_each_epoch, j + 1)
            plt.axis('off')
            plt.imshow(sample_images_generated[i, j].reshape(28, 28), cmap='gray')    
        plt.text(-169, 40, 'Epoch {}'.format(i + 1), fontsize=25) #adjust the text location
        if save:
            plt.savefig('./{}/{}.png'.format(folder_name, i + 1))
        plt.show()
    if save:
        gif_frames = []
        for i in range(epochs):
            gif_frames.append(imageio.imread('./{}/{}.png'.format(folder_name, i + 1)))
        imageio.mimsave('./{}/evolution.gif'.format(folder_name), gif_frames, duration=gif_frame_duration)

# %%
"""
Define the hyperparameters
"""
hyperparams={
    'noise_size': 100,
    'batch_size': 64,
    'epoch': 100,
    'generator_n_1': 256,
    'generator_n_2': 512,
    'generator_n_3': 1024,
    'generator_n_out': 784,
    'discriminator_n_1': 1024,
    'discriminator_n_2': 512,
    'discriminator_n_3': 256,
    'discriminator_n_out': 1,
    'learning_rate': 0.0001,
    'sample_size': 10
}
costs_history, sample_images_generated = MNIST_GAN(hyperparams)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Epoch 1/100 Time Elapsed: 31.19s
# Discriminator Cost: 0.7357 (Real: 0.2897 + Fake: 1.1818) Generator Cost: 0.5389
# Epoch 2/100 Time Elapsed: 29.72s
# Discriminator Cost: 0.7621 (Real: 0.6887 + Fake: 0.8356) Generator Cost: 0.7265
# Epoch 3/100 Time Elapsed: 29.58s
# Discriminator Cost: 0.5978 (Real: 0.7876 + Fake: 0.4081) Generator Cost: 1.3117
# Epoch 4/100 Time Elapsed: 29.51s
# Discriminator Cost: 0.6337 (Real: 0.8281 + Fake: 0.4393) Generator Cost: 1.3045
# Epoch 5/100 Time Elapsed: 29.60s
# Discriminator Cost: 0.3234 (Real: 0.3684 + Fake: 0.2784) Generator Cost: 1.9421
# Epoch 6/100 Time Elapsed: 29.15s
# Discriminator Cost: 0.3888 (Real: 0.4869 + Fake: 0.2908) Generator Cost: 1.9968
# Epoch 7/100 Time Elapsed: 29.51s
# Discriminator Cost: 0.4437 (Real: 0.3454 + Fake: 0.5420) Generator Cost: 1.6675
# Epoch 8/100 Time Elapsed: 29.29s
# Discriminator Cost: 0.7777 (Real: 0.6037 + Fake: 0.9516) Generator Cost: 1.0159
# Epoch 9/100 Time Elapsed: 29.71s
# Discriminator Cost: 0.5758 (Real: 0.4075 + Fake: 0.7441) Generator Cost: 1.4840
# Epoch 10/100 Time Elapsed: 29.75s
# Discriminator Cost: 0.4355 (Real: 0.6998 + Fake: 0.1712) Generator Cost: 3.2685
# Epoch 11/100 Time Elapsed: 29.71s
# Discriminator Cost: 0.6413 (Real: 0.5528 + Fake: 0.7297) Generator Cost: 1.4376
# Epoch 12/100 Time Elapsed: 29.36s
# Discriminator Cost: 0.2871 (Real: 0.3717 + Fake: 0.2024) Generator Cost: 2.8591
# Epoch 13/100 Time Elapsed: 28.51s
# Discriminator Cost: 0.2638 (Real: 0.3139 + Fake: 0.2137) Generator Cost: 3.0811
# Epoch 14/100 Time Elapsed: 29.40s
# Discriminator Cost: 0.2752 (Real: 0.2418 + Fake: 0.3086) Generator Cost: 2.2417
# Epoch 15/100 Time Elapsed: 29.35s
# Discriminator Cost: 0.6202 (Real: 1.0230 + Fake: 0.2173) Generator Cost: 2.7302
# Epoch 16/100 Time Elapsed: 29.44s
# Discriminator Cost: 0.4339 (Real: 0.2535 + Fake: 0.6142) Generator Cost: 2.3841
# Epoch 17/100 Time Elapsed: 29.50s
# Discriminator Cost: 0.3963 (Real: 0.4825 + Fake: 0.3100) Generator Cost: 2.2577
# Epoch 18/100 Time Elapsed: 29.66s
# Discriminator Cost: 0.6570 (Real: 1.2134 + Fake: 0.1005) Generator Cost: 4.4090
# Epoch 19/100 Time Elapsed: 28.86s
# Discriminator Cost: 0.3406 (Real: 0.4563 + Fake: 0.2250) Generator Cost: 2.4088
# Epoch 20/100 Time Elapsed: 29.62s
# Discriminator Cost: 0.4382 (Real: 0.5467 + Fake: 0.3298) Generator Cost: 2.4411
# Epoch 21/100 Time Elapsed: 29.15s
# Discriminator Cost: 0.6936 (Real: 0.7411 + Fake: 0.6460) Generator Cost: 1.4813
# Epoch 22/100 Time Elapsed: 29.67s
# Discriminator Cost: 0.3730 (Real: 0.5385 + Fake: 0.2076) Generator Cost: 2.4957
# Epoch 23/100 Time Elapsed: 29.15s
# Discriminator Cost: 0.4582 (Real: 0.6887 + Fake: 0.2277) Generator Cost: 2.3116
# Epoch 24/100 Time Elapsed: 29.19s
# Discriminator Cost: 0.3972 (Real: 0.4297 + Fake: 0.3648) Generator Cost: 1.8222
# Epoch 25/100 Time Elapsed: 28.64s
# Discriminator Cost: 0.4959 (Real: 0.5652 + Fake: 0.4266) Generator Cost: 1.8207
# Epoch 26/100 Time Elapsed: 29.64s
# Discriminator Cost: 0.4612 (Real: 0.3860 + Fake: 0.5364) Generator Cost: 1.4682
# Epoch 27/100 Time Elapsed: 28.56s
# Discriminator Cost: 0.5613 (Real: 0.7449 + Fake: 0.3778) Generator Cost: 1.7254
# Epoch 28/100 Time Elapsed: 29.56s
# Discriminator Cost: 0.4933 (Real: 0.4627 + Fake: 0.5240) Generator Cost: 1.2887
# Epoch 29/100 Time Elapsed: 29.34s
# Discriminator Cost: 0.5249 (Real: 0.4573 + Fake: 0.5925) Generator Cost: 1.2298
# Epoch 30/100 Time Elapsed: 29.52s
# Discriminator Cost: 0.5451 (Real: 0.4129 + Fake: 0.6774) Generator Cost: 1.2128
# Epoch 31/100 Time Elapsed: 29.51s
# Discriminator Cost: 0.5660 (Real: 0.7861 + Fake: 0.3458) Generator Cost: 1.9997
# Epoch 32/100 Time Elapsed: 29.66s
# Discriminator Cost: 0.5676 (Real: 0.5954 + Fake: 0.5397) Generator Cost: 1.3222
# Epoch 33/100 Time Elapsed: 29.43s
# Discriminator Cost: 0.5583 (Real: 0.7321 + Fake: 0.3846) Generator Cost: 1.7081
# Epoch 34/100 Time Elapsed: 29.42s
# Discriminator Cost: 0.4522 (Real: 0.4680 + Fake: 0.4365) Generator Cost: 1.5587
# Epoch 35/100 Time Elapsed: 29.24s
# Discriminator Cost: 0.4872 (Real: 0.4745 + Fake: 0.4999) Generator Cost: 1.4158
# Epoch 36/100 Time Elapsed: 29.84s
# Discriminator Cost: 0.5319 (Real: 0.7529 + Fake: 0.3110) Generator Cost: 1.8918
# Epoch 37/100 Time Elapsed: 29.15s
# Discriminator Cost: 0.5517 (Real: 0.5993 + Fake: 0.5041) Generator Cost: 1.4575
# Epoch 38/100 Time Elapsed: 29.15s
# Discriminator Cost: 0.5274 (Real: 0.5003 + Fake: 0.5545) Generator Cost: 1.3067
# Epoch 39/100 Time Elapsed: 29.42s
# Discriminator Cost: 0.4812 (Real: 0.5209 + Fake: 0.4416) Generator Cost: 1.4958
# Epoch 40/100 Time Elapsed: 28.35s
# Discriminator Cost: 0.5496 (Real: 0.3349 + Fake: 0.7643) Generator Cost: 0.9920
# Epoch 41/100 Time Elapsed: 28.52s
# Discriminator Cost: 0.5288 (Real: 0.6059 + Fake: 0.4518) Generator Cost: 1.4756
# Epoch 42/100 Time Elapsed: 29.41s
# Discriminator Cost: 0.5820 (Real: 0.4516 + Fake: 0.7124) Generator Cost: 1.1476
# Epoch 43/100 Time Elapsed: 29.64s
# Discriminator Cost: 0.5634 (Real: 0.8480 + Fake: 0.2787) Generator Cost: 2.0689
# Epoch 44/100 Time Elapsed: 29.44s
# Discriminator Cost: 0.5665 (Real: 0.4794 + Fake: 0.6536) Generator Cost: 1.1724
# Epoch 45/100 Time Elapsed: 29.69s
# Discriminator Cost: 0.5348 (Real: 0.4064 + Fake: 0.6632) Generator Cost: 1.1126
# Epoch 46/100 Time Elapsed: 28.61s
# Discriminator Cost: 0.4963 (Real: 0.5247 + Fake: 0.4680) Generator Cost: 1.4352
# Epoch 47/100 Time Elapsed: 29.29s
# Discriminator Cost: 0.4908 (Real: 0.5176 + Fake: 0.4641) Generator Cost: 1.3850
# Epoch 48/100 Time Elapsed: 28.19s
# Discriminator Cost: 0.5443 (Real: 0.6872 + Fake: 0.4014) Generator Cost: 1.6391
# Epoch 49/100 Time Elapsed: 29.37s
# Discriminator Cost: 0.4998 (Real: 0.5408 + Fake: 0.4588) Generator Cost: 1.5622
# Epoch 50/100 Time Elapsed: 29.38s
# Discriminator Cost: 0.5288 (Real: 0.6458 + Fake: 0.4118) Generator Cost: 1.5964
# Epoch 51/100 Time Elapsed: 29.55s
# Discriminator Cost: 0.5313 (Real: 0.5785 + Fake: 0.4841) Generator Cost: 1.5031
# Epoch 52/100 Time Elapsed: 29.22s
# Discriminator Cost: 0.6135 (Real: 0.3733 + Fake: 0.8537) Generator Cost: 0.9713
# Epoch 53/100 Time Elapsed: 29.83s
# Discriminator Cost: 0.5537 (Real: 0.7056 + Fake: 0.4019) Generator Cost: 1.5997
# Epoch 54/100 Time Elapsed: 29.56s
# Discriminator Cost: 0.5427 (Real: 0.6014 + Fake: 0.4841) Generator Cost: 1.4218
# Epoch 55/100 Time Elapsed: 29.50s
# Discriminator Cost: 0.5689 (Real: 0.7185 + Fake: 0.4192) Generator Cost: 1.5746
# Epoch 56/100 Time Elapsed: 29.53s
# Discriminator Cost: 0.5604 (Real: 0.4418 + Fake: 0.6790) Generator Cost: 1.0961
# Epoch 57/100 Time Elapsed: 29.25s
# Discriminator Cost: 0.5533 (Real: 0.6866 + Fake: 0.4200) Generator Cost: 1.5798
# Epoch 58/100 Time Elapsed: 29.24s
# Discriminator Cost: 0.5837 (Real: 0.6490 + Fake: 0.5183) Generator Cost: 1.4276
# Epoch 59/100 Time Elapsed: 29.54s
# Discriminator Cost: 0.5515 (Real: 0.7017 + Fake: 0.4013) Generator Cost: 1.6238
# Epoch 60/100 Time Elapsed: 29.29s
# Discriminator Cost: 0.5242 (Real: 0.4999 + Fake: 0.5485) Generator Cost: 1.3247
# Epoch 61/100 Time Elapsed: 28.75s
# Discriminator Cost: 0.5737 (Real: 0.6716 + Fake: 0.4758) Generator Cost: 1.4459
# Epoch 62/100 Time Elapsed: 29.10s
# Discriminator Cost: 0.5300 (Real: 0.6810 + Fake: 0.3789) Generator Cost: 1.5905
# Epoch 63/100 Time Elapsed: 29.10s
# Discriminator Cost: 0.5745 (Real: 0.5903 + Fake: 0.5587) Generator Cost: 1.3191
# Epoch 64/100 Time Elapsed: 28.34s
# Discriminator Cost: 0.5800 (Real: 0.4654 + Fake: 0.6947) Generator Cost: 1.0631
# Epoch 65/100 Time Elapsed: 29.50s
# Discriminator Cost: 0.5558 (Real: 0.4544 + Fake: 0.6571) Generator Cost: 1.0896
# Epoch 66/100 Time Elapsed: 29.30s
# Discriminator Cost: 0.5202 (Real: 0.4901 + Fake: 0.5503) Generator Cost: 1.2373
# Epoch 67/100 Time Elapsed: 29.43s
# Discriminator Cost: 0.5604 (Real: 0.7091 + Fake: 0.4117) Generator Cost: 1.5628
# Epoch 68/100 Time Elapsed: 29.60s
# Discriminator Cost: 0.5879 (Real: 0.3700 + Fake: 0.8059) Generator Cost: 0.8943
# Epoch 69/100 Time Elapsed: 29.61s
# Discriminator Cost: 0.5414 (Real: 0.6714 + Fake: 0.4114) Generator Cost: 1.5429
# Epoch 70/100 Time Elapsed: 29.06s
# Discriminator Cost: 0.5713 (Real: 0.4697 + Fake: 0.6729) Generator Cost: 1.0937
# Epoch 71/100 Time Elapsed: 29.51s
# Discriminator Cost: 0.5454 (Real: 0.5957 + Fake: 0.4950) Generator Cost: 1.3052
# Epoch 72/100 Time Elapsed: 29.28s
# Discriminator Cost: 0.5711 (Real: 0.7183 + Fake: 0.4240) Generator Cost: 1.5318
# Epoch 73/100 Time Elapsed: 29.42s
# Discriminator Cost: 0.5786 (Real: 0.3858 + Fake: 0.7713) Generator Cost: 0.9127
# Epoch 74/100 Time Elapsed: 28.85s
# Discriminator Cost: 0.5720 (Real: 0.5005 + Fake: 0.6435) Generator Cost: 1.1279
# Epoch 75/100 Time Elapsed: 29.37s
# Discriminator Cost: 0.5389 (Real: 0.6878 + Fake: 0.3900) Generator Cost: 1.5667
# Epoch 76/100 Time Elapsed: 28.47s
# Discriminator Cost: 0.5515 (Real: 0.5332 + Fake: 0.5698) Generator Cost: 1.1656
# Epoch 77/100 Time Elapsed: 29.57s
# Discriminator Cost: 0.5738 (Real: 0.7584 + Fake: 0.3891) Generator Cost: 1.5801
# Epoch 78/100 Time Elapsed: 29.67s
# Discriminator Cost: 0.5738 (Real: 0.5367 + Fake: 0.6109) Generator Cost: 1.1541
# Epoch 79/100 Time Elapsed: 29.57s
# Discriminator Cost: 0.6359 (Real: 1.0108 + Fake: 0.2610) Generator Cost: 2.0306
# Epoch 80/100 Time Elapsed: 29.54s
# Discriminator Cost: 0.6141 (Real: 0.4583 + Fake: 0.7698) Generator Cost: 0.9799
# Epoch 81/100 Time Elapsed: 29.42s
# Discriminator Cost: 0.5878 (Real: 0.7564 + Fake: 0.4192) Generator Cost: 1.5271
# Epoch 82/100 Time Elapsed: 29.03s
# Discriminator Cost: 0.5773 (Real: 0.5164 + Fake: 0.6381) Generator Cost: 1.1328
# Epoch 83/100 Time Elapsed: 29.41s
# Discriminator Cost: 0.5325 (Real: 0.6265 + Fake: 0.4385) Generator Cost: 1.4549
# Epoch 84/100 Time Elapsed: 29.59s
# Discriminator Cost: 0.5782 (Real: 0.6043 + Fake: 0.5521) Generator Cost: 1.2439
# Epoch 85/100 Time Elapsed: 29.40s
# Discriminator Cost: 0.5751 (Real: 0.6856 + Fake: 0.4645) Generator Cost: 1.3637
# Epoch 86/100 Time Elapsed: 29.65s
# Discriminator Cost: 0.5851 (Real: 0.7057 + Fake: 0.4645) Generator Cost: 1.4178
# Epoch 87/100 Time Elapsed: 27.94s
# Discriminator Cost: 0.5713 (Real: 0.4794 + Fake: 0.6632) Generator Cost: 1.0420
# Epoch 88/100 Time Elapsed: 29.52s
# Discriminator Cost: 0.5986 (Real: 0.4684 + Fake: 0.7287) Generator Cost: 0.9643
# Epoch 89/100 Time Elapsed: 29.80s
# Discriminator Cost: 0.5744 (Real: 0.6330 + Fake: 0.5157) Generator Cost: 1.3063
# Epoch 90/100 Time Elapsed: 29.60s
# Discriminator Cost: 0.5742 (Real: 0.4963 + Fake: 0.6522) Generator Cost: 1.0506
# Epoch 91/100 Time Elapsed: 29.61s
# Discriminator Cost: 0.5816 (Real: 0.4846 + Fake: 0.6787) Generator Cost: 1.0226
# Epoch 92/100 Time Elapsed: 29.13s
# Discriminator Cost: 0.5848 (Real: 0.6568 + Fake: 0.5127) Generator Cost: 1.3172
# Epoch 93/100 Time Elapsed: 29.44s
# Discriminator Cost: 0.5736 (Real: 0.5755 + Fake: 0.5718) Generator Cost: 1.1970
# Epoch 94/100 Time Elapsed: 29.26s
# Discriminator Cost: 0.6091 (Real: 0.4438 + Fake: 0.7744) Generator Cost: 0.9360
# Epoch 95/100 Time Elapsed: 29.22s
# Discriminator Cost: 0.5567 (Real: 0.6357 + Fake: 0.4777) Generator Cost: 1.3413
# Epoch 96/100 Time Elapsed: 29.77s
# Discriminator Cost: 0.5873 (Real: 0.5067 + Fake: 0.6679) Generator Cost: 1.0442
# Epoch 97/100 Time Elapsed: 29.33s
# Discriminator Cost: 0.5746 (Real: 0.6933 + Fake: 0.4559) Generator Cost: 1.3585
# Epoch 98/100 Time Elapsed: 29.36s
# Discriminator Cost: 0.5748 (Real: 0.6377 + Fake: 0.5119) Generator Cost: 1.3014
# Epoch 99/100 Time Elapsed: 28.49s
# Discriminator Cost: 0.6211 (Real: 0.3749 + Fake: 0.8673) Generator Cost: 0.8283
# Epoch 100/100 Time Elapsed: 29.17s
# Discriminator Cost: 0.5633 (Real: 0.6559 + Fake: 0.4708) Generator Cost: 1.3402

# %%
show_graphs(costs_history)

# %%
show_save_samples(sample_images_generated, save=True, gif_frame_duration=0.3)
