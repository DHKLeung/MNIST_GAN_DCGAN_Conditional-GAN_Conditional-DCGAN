# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import imageio
from tensorflow.examples.tutorials.mnist import input_data
os.environ['CUDA_VISIBLE_DEVICES'] = '4'
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
"""
Compute the time elapsed
"""
def tic():
    global tic_time
    tic_time = time.time()
    
def toc():
    return time.time() - tic_time

# %%
"""
Load MNIST data
Return: all 70000(train + val + test) images
"""
def load_data():
    mnist = input_data.read_data_sets('MNIST_data/')
    images = np.append(np.append(mnist.train.images, mnist.validation.images, axis=0), mnist.test.images, axis=0)
    return images #shape = (70000, 784)

# %%
"""
Define the Generator
"""
def generator(noises_input, n_1, n_2, n_3, n_out):
    with tf.variable_scope('generator'):
        Z1 = tf.contrib.layers.fully_connected(noises_input, n_1, activation_fn=None, scope='Z1')
        A1 = tf.nn.leaky_relu(Z1, name='A1')
        Z2 = tf.contrib.layers.fully_connected(A1, n_2, activation_fn=None, scope='Z2')
        A2 = tf.nn.leaky_relu(Z2, name='A2')
        Z3 = tf.contrib.layers.fully_connected(A2, n_3, activation_fn=None, scope='Z3')
        A3 = tf.nn.leaky_relu(Z3, name='A3')
        Z_out = tf.contrib.layers.fully_connected(A3, n_out, activation_fn=None, scope='Z_out')
        A_out = tf.nn.tanh(Z_out, name='A_out')
    return A_out

# %%
"""
Define the Discriminator
"""
def discriminator(images_input, n_1, n_2, n_3, n_out, reuse=False):
    with tf.variable_scope('discriminator', reuse=reuse):
        Z1 = tf.contrib.layers.fully_connected(images_input, n_1, activation_fn=None, scope='Z1')
        A1 = tf.nn.leaky_relu(Z1, name='A1')
        A1_dropout = tf.nn.dropout(A1, 0.7, name='A1_dropout')
        Z2 = tf.contrib.layers.fully_connected(A1_dropout, n_2, activation_fn=None, scope='Z2')
        A2 = tf.nn.leaky_relu(Z2, name='A2')
        A2_dropout = tf.nn.dropout(A2, 0.7, name='A2_dropout')
        Z3 = tf.contrib.layers.fully_connected(A2_dropout, n_3, activation_fn=None, scope='Z3')
        A3 = tf.nn.leaky_relu(Z3, name='A3')
        A3_dropout = tf.nn.dropout(A3, 0.7, name='A3_dropout')
        Z_out = tf.contrib.layers.fully_connected(A3_dropout, n_out, activation_fn=None, scope='Z_out')
    return Z_out

# %%
"""
Define and Train Generative Adversarial Networks(GANs) Model
Return: history of costs(both generator and discriminator) 
        samples generated in each epoch
"""
def MNIST_GAN(hyperparams):
    tf.reset_default_graph()
    #Load data#
    mnist_images = load_data() * 2 - 1
    
    #Hyperparameters settings and properties#
    noise_size = hyperparams['noise_size']
    batch_size = hyperparams['batch_size']
    label_smooth = hyperparams['label_smooth']
    epoch = hyperparams['epoch']
    generator_n_1 = hyperparams['generator_n_1']
    generator_n_2 = hyperparams['generator_n_2']
    generator_n_3 = hyperparams['generator_n_3']
    generator_n_out = hyperparams['generator_n_out']
    discriminator_n_1 = hyperparams['discriminator_n_1']
    discriminator_n_2 = hyperparams['discriminator_n_2']
    discriminator_n_3 = hyperparams['discriminator_n_3']
    discriminator_n_out = hyperparams['discriminator_n_out']
    gen_learning_rate = hyperparams['gen_learning_rate']
    dis_learning_rate = hyperparams['dis_learning_rate']
    adam_beta1 = hyperparams['adam_beta1']
    sample_size = hyperparams['sample_size']
    data_size = mnist_images.shape[0]
    image_size = mnist_images.shape[1]
    total_batches = np.ceil(data_size / batch_size).astype(np.int32)
    
    #Define placeholders#
    real_images = tf.placeholder(tf.float32, (None, image_size), name='real_images')
    noises_input = tf.placeholder(tf.float32, (None, noise_size), name='noises_input')
    
    #Define the outputs of generator and discriminator#
    fake_images = generator(noises_input, generator_n_1, generator_n_2, generator_n_3, generator_n_out)
    real_logits = discriminator(real_images, discriminator_n_1, discriminator_n_2, discriminator_n_3, discriminator_n_out)
    fake_logits = discriminator(fake_images, discriminator_n_1, discriminator_n_2, discriminator_n_3, discriminator_n_out, reuse=True)
    
    #Define costs of discriminator(fake and real data) and generator#
    dis_real_cost = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=real_logits, labels=tf.multiply(tf.ones_like(real_logits), (1. - label_smooth))))
    dis_fake_cost = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logits, labels=tf.zeros_like(fake_logits)))
    dis_cost = tf.divide(tf.add(dis_real_cost, dis_fake_cost), 2)
    gen_cost = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logits, labels=tf.ones_like(fake_logits)))
    
    #Define the optimization#
    trainable_vars = tf.trainable_variables()
    gen_vars = [var for var in trainable_vars if var.name.startswith('generator')]
    dis_vars = [var for var in trainable_vars if var.name.startswith('discriminator')]
    gen_optimize = tf.train.AdamOptimizer(learning_rate=gen_learning_rate, beta1=adam_beta1, name='gen_optimize').minimize(gen_cost, var_list=gen_vars)
    dis_optimize = tf.train.AdamOptimizer(learning_rate=dis_learning_rate, beta1=adam_beta1, name='dis_optimize').minimize(dis_cost, var_list=dis_vars)
    
    #Training#
    costs_history = []
    sample_images_generated = np.empty((0, sample_size, image_size))
    sample_noises_input = np.random.uniform(low=-1, high=1, size=(sample_size, noise_size))
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(epoch):
            tic()
            dis_cost_real_epoch = 0.
            dis_cost_fake_epoch = 0.
            dis_cost_epoch = 0.
            gen_cost_epoch = 0.
            for j in range(total_batches):
                index_front = j * batch_size
                index_end = (j + 1) * batch_size if (j + 1) * batch_size < data_size else data_size
                images_batch = mnist_images[index_front:index_end].reshape(-1, image_size)
                noises_batch = np.random.uniform(low=-1, high=1, size=(index_end - index_front, noise_size))
                _, dis_cost_real_iter, dis_cost_fake_iter, dis_cost_iter = sess.run([dis_optimize, dis_real_cost, dis_fake_cost, dis_cost], feed_dict={real_images:images_batch, noises_input:noises_batch})
                _, gen_cost_iter = sess.run([gen_optimize, gen_cost], feed_dict={noises_input:noises_batch})
                dis_cost_real_epoch += dis_cost_real_iter / data_size
                dis_cost_fake_epoch += dis_cost_fake_iter / data_size
                dis_cost_epoch += dis_cost_iter / data_size
                gen_cost_epoch += gen_cost_iter / data_size
            costs_history.append((dis_cost_real_epoch, dis_cost_fake_epoch, dis_cost_epoch, gen_cost_epoch))
            sample_images_generated_epoch = sess.run(fake_images, feed_dict={noises_input:sample_noises_input}).reshape(1, -1, image_size)
            sample_images_generated = np.append(sample_images_generated, sample_images_generated_epoch, axis=0)
            print('Epoch {}/{} Time Elapsed: {:.2f}s'.format(i + 1, epoch, toc()))
            print('Discriminator Cost: {:.4f} (Real: {:.4f} + Fake: {:.4f}) Generator Cost: {:.4f}'.format(dis_cost_epoch, dis_cost_real_epoch, dis_cost_fake_epoch, gen_cost_epoch))
        return costs_history, sample_images_generated

# %%
"""
Show graphs of costs of discriminator and generator
"""
def show_graphs(costs_history):
    costs = np.array(costs_history).T
    plt.figure(figsize=(20, 10))
    plt.ylabel('Cost')
    plt.xlabel('Epoch')
    plt.title('Cost - Epoch')
    plt.plot(costs[0], label='Discriminator Real Cost')
    plt.plot(costs[1], label='Discriminator Fake Cost')
    plt.plot(costs[2], label='Discriminator Total Cost')
    plt.plot(costs[3], label='Generator Cost')
    plt.legend(loc='best')
    plt.show()

# %%
"""
Show and save samples
Variables: 
    sample_images_generated shape: (num of epochs, num of samples in each epoch, num of rows of image, num of column of image)
    save: True if want to save the figures(pngs and gifs)
    folder_name: create the folder if not exists, save figures to the specific folder
"""
def show_save_samples(sample_images_generated, save=False, folder_name='MNIST_GAN_samples', gif_frame_duration=0.25):
    #Scale images to the range of [0, 1]#
    sample_images_generated = (sample_images_generated + 1) / 2
    
    #Create folder if not exists#
    if save and not os.path.exists('./{}'.format(folder_name)):
        os.mkdir(folder_name)
        
    #Parameters#
    epochs = sample_images_generated.shape[0]
    num_sample_each_epoch = sample_images_generated.shape[1]
    
    #Output and save figures#
    for i in range(epochs):
        plt.figure(figsize=(2 * num_sample_each_epoch, 5))
        for j in range(num_sample_each_epoch):
            plt.subplot(1, num_sample_each_epoch, j + 1)
            plt.axis('off')
            plt.imshow(sample_images_generated[i, j].reshape(28, 28), cmap='gray')    
        plt.text(-169, 40, 'Epoch {}'.format(i + 1), fontsize=25) #adjust the text location
        if save:
            plt.savefig('./{}/{}.png'.format(folder_name, i + 1))
        plt.show()
        
    #Make GIF#
    if save:
        gif_frames = []
        for i in range(epochs):
            gif_frames.append(imageio.imread('./{}/{}.png'.format(folder_name, i + 1)))
        imageio.mimsave('./{}/evolution.gif'.format(folder_name), gif_frames, duration=gif_frame_duration)

# %%
"""
Define the hyperparameters
"""
hyperparams={
    'noise_size': 100,
    'batch_size': 128,
    'label_smooth': 0.1,
    'epoch': 100,
    'generator_n_1': 256,
    'generator_n_2': 512,
    'generator_n_3': 1024,
    'generator_n_out': 784,
    'discriminator_n_1': 1024,
    'discriminator_n_2': 512,
    'discriminator_n_3': 256,
    'discriminator_n_out': 1,
    'gen_learning_rate': 0.0001,
    'dis_learning_rate': 0.0001,
    'adam_beta1': 0.5,
    'sample_size': 10
}
costs_history, sample_images_generated = MNIST_GAN(hyperparams)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Epoch 1/100 Time Elapsed: 5.82s
# Discriminator Cost: 0.4674 (Real: 0.4438 + Fake: 0.4911) Generator Cost: 1.4404
# Epoch 2/100 Time Elapsed: 5.14s
# Discriminator Cost: 0.3832 (Real: 0.5309 + Fake: 0.2356) Generator Cost: 2.5431
# Epoch 3/100 Time Elapsed: 5.35s
# Discriminator Cost: 0.3532 (Real: 0.5325 + Fake: 0.1740) Generator Cost: 2.8154
# Epoch 4/100 Time Elapsed: 5.44s
# Discriminator Cost: 0.3342 (Real: 0.5286 + Fake: 0.1397) Generator Cost: 2.9334
# Epoch 5/100 Time Elapsed: 5.49s
# Discriminator Cost: 0.3280 (Real: 0.5254 + Fake: 0.1307) Generator Cost: 2.9468
# Epoch 6/100 Time Elapsed: 5.20s
# Discriminator Cost: 0.3480 (Real: 0.5391 + Fake: 0.1569) Generator Cost: 2.8203
# Epoch 7/100 Time Elapsed: 4.97s
# Discriminator Cost: 0.3700 (Real: 0.5536 + Fake: 0.1865) Generator Cost: 2.7059
# Epoch 8/100 Time Elapsed: 5.68s
# Discriminator Cost: 0.3769 (Real: 0.5591 + Fake: 0.1947) Generator Cost: 2.6323
# Epoch 9/100 Time Elapsed: 5.58s
# Discriminator Cost: 0.3920 (Real: 0.5664 + Fake: 0.2176) Generator Cost: 2.5884
# Epoch 10/100 Time Elapsed: 5.54s
# Discriminator Cost: 0.4199 (Real: 0.5862 + Fake: 0.2537) Generator Cost: 2.3501
# Epoch 11/100 Time Elapsed: 5.74s
# Discriminator Cost: 0.4384 (Real: 0.5996 + Fake: 0.2773) Generator Cost: 2.1511
# Epoch 12/100 Time Elapsed: 5.38s
# Discriminator Cost: 0.4514 (Real: 0.6099 + Fake: 0.2929) Generator Cost: 2.0609
# Epoch 13/100 Time Elapsed: 5.82s
# Discriminator Cost: 0.4610 (Real: 0.6169 + Fake: 0.3052) Generator Cost: 1.9779
# Epoch 14/100 Time Elapsed: 5.93s
# Discriminator Cost: 0.4811 (Real: 0.6313 + Fake: 0.3309) Generator Cost: 1.8600
# Epoch 15/100 Time Elapsed: 5.95s
# Discriminator Cost: 0.4826 (Real: 0.6326 + Fake: 0.3326) Generator Cost: 1.8289
# Epoch 16/100 Time Elapsed: 5.87s
# Discriminator Cost: 0.4852 (Real: 0.6341 + Fake: 0.3363) Generator Cost: 1.8109
# Epoch 17/100 Time Elapsed: 5.83s
# Discriminator Cost: 0.4847 (Real: 0.6364 + Fake: 0.3330) Generator Cost: 1.8101
# Epoch 18/100 Time Elapsed: 5.79s
# Discriminator Cost: 0.4966 (Real: 0.6444 + Fake: 0.3488) Generator Cost: 1.7440
# Epoch 19/100 Time Elapsed: 5.70s
# Discriminator Cost: 0.5006 (Real: 0.6450 + Fake: 0.3562) Generator Cost: 1.7247
# Epoch 20/100 Time Elapsed: 6.07s
# Discriminator Cost: 0.5047 (Real: 0.6484 + Fake: 0.3610) Generator Cost: 1.7038
# Epoch 21/100 Time Elapsed: 5.89s
# Discriminator Cost: 0.5118 (Real: 0.6545 + Fake: 0.3691) Generator Cost: 1.6587
# Epoch 22/100 Time Elapsed: 6.08s
# Discriminator Cost: 0.5094 (Real: 0.6537 + Fake: 0.3651) Generator Cost: 1.6623
# Epoch 23/100 Time Elapsed: 6.06s
# Discriminator Cost: 0.5118 (Real: 0.6549 + Fake: 0.3687) Generator Cost: 1.6486
# Epoch 24/100 Time Elapsed: 5.88s
# Discriminator Cost: 0.5184 (Real: 0.6590 + Fake: 0.3778) Generator Cost: 1.5989
# Epoch 25/100 Time Elapsed: 5.76s
# Discriminator Cost: 0.5233 (Real: 0.6627 + Fake: 0.3838) Generator Cost: 1.5902
# Epoch 26/100 Time Elapsed: 6.04s
# Discriminator Cost: 0.5226 (Real: 0.6633 + Fake: 0.3818) Generator Cost: 1.5891
# Epoch 27/100 Time Elapsed: 6.01s
# Discriminator Cost: 0.5278 (Real: 0.6673 + Fake: 0.3883) Generator Cost: 1.5567
# Epoch 28/100 Time Elapsed: 5.97s
# Discriminator Cost: 0.5304 (Real: 0.6681 + Fake: 0.3926) Generator Cost: 1.5395
# Epoch 29/100 Time Elapsed: 5.82s
# Discriminator Cost: 0.5309 (Real: 0.6690 + Fake: 0.3929) Generator Cost: 1.5432
# Epoch 30/100 Time Elapsed: 5.46s
# Discriminator Cost: 0.5343 (Real: 0.6710 + Fake: 0.3976) Generator Cost: 1.5198
# Epoch 31/100 Time Elapsed: 6.13s
# Discriminator Cost: 0.5354 (Real: 0.6720 + Fake: 0.3988) Generator Cost: 1.5134
# Epoch 32/100 Time Elapsed: 6.00s
# Discriminator Cost: 0.5379 (Real: 0.6745 + Fake: 0.4013) Generator Cost: 1.5018
# Epoch 33/100 Time Elapsed: 5.98s
# Discriminator Cost: 0.5410 (Real: 0.6763 + Fake: 0.4058) Generator Cost: 1.4814
# Epoch 34/100 Time Elapsed: 6.11s
# Discriminator Cost: 0.5416 (Real: 0.6773 + Fake: 0.4060) Generator Cost: 1.4827
# Epoch 35/100 Time Elapsed: 5.78s
# Discriminator Cost: 0.5422 (Real: 0.6777 + Fake: 0.4067) Generator Cost: 1.4808
# Epoch 36/100 Time Elapsed: 6.30s
# Discriminator Cost: 0.5441 (Real: 0.6785 + Fake: 0.4096) Generator Cost: 1.4641
# Epoch 37/100 Time Elapsed: 5.98s
# Discriminator Cost: 0.5468 (Real: 0.6797 + Fake: 0.4138) Generator Cost: 1.4520
# Epoch 38/100 Time Elapsed: 6.29s
# Discriminator Cost: 0.5459 (Real: 0.6799 + Fake: 0.4119) Generator Cost: 1.4509
# Epoch 39/100 Time Elapsed: 6.16s
# Discriminator Cost: 0.5478 (Real: 0.6813 + Fake: 0.4143) Generator Cost: 1.4511
# Epoch 40/100 Time Elapsed: 6.30s
# Discriminator Cost: 0.5490 (Real: 0.6833 + Fake: 0.4148) Generator Cost: 1.4416
# Epoch 41/100 Time Elapsed: 5.88s
# Discriminator Cost: 0.5495 (Real: 0.6828 + Fake: 0.4163) Generator Cost: 1.4362
# Epoch 42/100 Time Elapsed: 5.91s
# Discriminator Cost: 0.5504 (Real: 0.6837 + Fake: 0.4171) Generator Cost: 1.4362
# Epoch 43/100 Time Elapsed: 6.14s
# Discriminator Cost: 0.5498 (Real: 0.6829 + Fake: 0.4168) Generator Cost: 1.4376
# Epoch 44/100 Time Elapsed: 5.83s
# Discriminator Cost: 0.5486 (Real: 0.6818 + Fake: 0.4155) Generator Cost: 1.4427
# Epoch 45/100 Time Elapsed: 5.55s
# Discriminator Cost: 0.5507 (Real: 0.6836 + Fake: 0.4178) Generator Cost: 1.4317
# Epoch 46/100 Time Elapsed: 5.67s
# Discriminator Cost: 0.5546 (Real: 0.6860 + Fake: 0.4231) Generator Cost: 1.4176
# Epoch 47/100 Time Elapsed: 6.04s
# Discriminator Cost: 0.5546 (Real: 0.6867 + Fake: 0.4225) Generator Cost: 1.4181
# Epoch 48/100 Time Elapsed: 5.86s
# Discriminator Cost: 0.5550 (Real: 0.6877 + Fake: 0.4223) Generator Cost: 1.4184
# Epoch 49/100 Time Elapsed: 6.16s
# Discriminator Cost: 0.5546 (Real: 0.6878 + Fake: 0.4214) Generator Cost: 1.4130
# Epoch 50/100 Time Elapsed: 5.63s
# Discriminator Cost: 0.5559 (Real: 0.6869 + Fake: 0.4249) Generator Cost: 1.4079
# Epoch 51/100 Time Elapsed: 5.76s
# Discriminator Cost: 0.5579 (Real: 0.6894 + Fake: 0.4264) Generator Cost: 1.3969
# Epoch 52/100 Time Elapsed: 5.82s
# Discriminator Cost: 0.5560 (Real: 0.6875 + Fake: 0.4245) Generator Cost: 1.4029
# Epoch 53/100 Time Elapsed: 5.78s
# Discriminator Cost: 0.5575 (Real: 0.6880 + Fake: 0.4271) Generator Cost: 1.4030
# Epoch 54/100 Time Elapsed: 6.08s
# Discriminator Cost: 0.5591 (Real: 0.6893 + Fake: 0.4288) Generator Cost: 1.3921
# Epoch 55/100 Time Elapsed: 5.89s
# Discriminator Cost: 0.5587 (Real: 0.6888 + Fake: 0.4287) Generator Cost: 1.3952
# Epoch 56/100 Time Elapsed: 6.09s
# Discriminator Cost: 0.5596 (Real: 0.6900 + Fake: 0.4292) Generator Cost: 1.3891
# Epoch 57/100 Time Elapsed: 6.17s
# Discriminator Cost: 0.5619 (Real: 0.6911 + Fake: 0.4327) Generator Cost: 1.3819
# Epoch 58/100 Time Elapsed: 6.05s
# Discriminator Cost: 0.5625 (Real: 0.6915 + Fake: 0.4334) Generator Cost: 1.3793
# Epoch 59/100 Time Elapsed: 5.93s
# Discriminator Cost: 0.5624 (Real: 0.6909 + Fake: 0.4340) Generator Cost: 1.3826
# Epoch 60/100 Time Elapsed: 5.97s
# Discriminator Cost: 0.5632 (Real: 0.6912 + Fake: 0.4352) Generator Cost: 1.3649
# Epoch 61/100 Time Elapsed: 5.30s
# Discriminator Cost: 0.5629 (Real: 0.6930 + Fake: 0.4328) Generator Cost: 1.3836
# Epoch 62/100 Time Elapsed: 5.86s
# Discriminator Cost: 0.5613 (Real: 0.6905 + Fake: 0.4321) Generator Cost: 1.3784
# Epoch 63/100 Time Elapsed: 6.05s
# Discriminator Cost: 0.5659 (Real: 0.6950 + Fake: 0.4368) Generator Cost: 1.3610
# Epoch 64/100 Time Elapsed: 5.91s
# Discriminator Cost: 0.5643 (Real: 0.6936 + Fake: 0.4351) Generator Cost: 1.3656
# Epoch 65/100 Time Elapsed: 5.99s
# Discriminator Cost: 0.5654 (Real: 0.6936 + Fake: 0.4372) Generator Cost: 1.3682
# Epoch 66/100 Time Elapsed: 5.50s
# Discriminator Cost: 0.5662 (Real: 0.6945 + Fake: 0.4379) Generator Cost: 1.3611
# Epoch 67/100 Time Elapsed: 6.20s
# Discriminator Cost: 0.5653 (Real: 0.6938 + Fake: 0.4368) Generator Cost: 1.3648
# Epoch 68/100 Time Elapsed: 5.79s
# Discriminator Cost: 0.5672 (Real: 0.6965 + Fake: 0.4379) Generator Cost: 1.3553
# Epoch 69/100 Time Elapsed: 5.53s
# Discriminator Cost: 0.5683 (Real: 0.6963 + Fake: 0.4403) Generator Cost: 1.3466
# Epoch 70/100 Time Elapsed: 6.44s
# Discriminator Cost: 0.5689 (Real: 0.6964 + Fake: 0.4413) Generator Cost: 1.3407
# Epoch 71/100 Time Elapsed: 5.54s
# Discriminator Cost: 0.5689 (Real: 0.6968 + Fake: 0.4411) Generator Cost: 1.3502
# Epoch 72/100 Time Elapsed: 5.89s
# Discriminator Cost: 0.5692 (Real: 0.6965 + Fake: 0.4420) Generator Cost: 1.3404
# Epoch 73/100 Time Elapsed: 5.78s
# Discriminator Cost: 0.5689 (Real: 0.6963 + Fake: 0.4414) Generator Cost: 1.3370
# Epoch 74/100 Time Elapsed: 6.33s
# Discriminator Cost: 0.5690 (Real: 0.6972 + Fake: 0.4408) Generator Cost: 1.3438
# Epoch 75/100 Time Elapsed: 5.95s
# Discriminator Cost: 0.5703 (Real: 0.6975 + Fake: 0.4430) Generator Cost: 1.3402
# Epoch 76/100 Time Elapsed: 6.28s
# Discriminator Cost: 0.5697 (Real: 0.6969 + Fake: 0.4424) Generator Cost: 1.3382
# Epoch 77/100 Time Elapsed: 5.45s
# Discriminator Cost: 0.5719 (Real: 0.6986 + Fake: 0.4452) Generator Cost: 1.3268
# Epoch 78/100 Time Elapsed: 5.76s
# Discriminator Cost: 0.5709 (Real: 0.6974 + Fake: 0.4443) Generator Cost: 1.3371
# Epoch 79/100 Time Elapsed: 6.20s
# Discriminator Cost: 0.5726 (Real: 0.6991 + Fake: 0.4461) Generator Cost: 1.3257
# Epoch 80/100 Time Elapsed: 6.07s
# Discriminator Cost: 0.5713 (Real: 0.6981 + Fake: 0.4444) Generator Cost: 1.3273
# Epoch 81/100 Time Elapsed: 6.19s
# Discriminator Cost: 0.5723 (Real: 0.6989 + Fake: 0.4456) Generator Cost: 1.3258
# Epoch 82/100 Time Elapsed: 5.90s
# Discriminator Cost: 0.5724 (Real: 0.6992 + Fake: 0.4456) Generator Cost: 1.3238
# Epoch 83/100 Time Elapsed: 6.08s
# Discriminator Cost: 0.5737 (Real: 0.7007 + Fake: 0.4466) Generator Cost: 1.3154
# Epoch 84/100 Time Elapsed: 5.87s
# Discriminator Cost: 0.5733 (Real: 0.6995 + Fake: 0.4471) Generator Cost: 1.3193
# Epoch 85/100 Time Elapsed: 6.07s
# Discriminator Cost: 0.5736 (Real: 0.7006 + Fake: 0.4465) Generator Cost: 1.3186
# Epoch 86/100 Time Elapsed: 5.75s
# Discriminator Cost: 0.5740 (Real: 0.7002 + Fake: 0.4477) Generator Cost: 1.3153
# Epoch 87/100 Time Elapsed: 6.26s
# Discriminator Cost: 0.5753 (Real: 0.7014 + Fake: 0.4491) Generator Cost: 1.3093
# Epoch 88/100 Time Elapsed: 5.46s
# Discriminator Cost: 0.5743 (Real: 0.7003 + Fake: 0.4483) Generator Cost: 1.3087
# Epoch 89/100 Time Elapsed: 5.60s
# Discriminator Cost: 0.5769 (Real: 0.7021 + Fake: 0.4517) Generator Cost: 1.3025
# Epoch 90/100 Time Elapsed: 6.24s
# Discriminator Cost: 0.5756 (Real: 0.7010 + Fake: 0.4503) Generator Cost: 1.3072
# Epoch 91/100 Time Elapsed: 6.02s
# Discriminator Cost: 0.5782 (Real: 0.7030 + Fake: 0.4534) Generator Cost: 1.2996
# Epoch 92/100 Time Elapsed: 6.30s
# Discriminator Cost: 0.5784 (Real: 0.7032 + Fake: 0.4536) Generator Cost: 1.2945
# Epoch 93/100 Time Elapsed: 6.09s
# Discriminator Cost: 0.5791 (Real: 0.7039 + Fake: 0.4544) Generator Cost: 1.2959
# Epoch 94/100 Time Elapsed: 5.86s
# Discriminator Cost: 0.5792 (Real: 0.7038 + Fake: 0.4545) Generator Cost: 1.2921
# Epoch 95/100 Time Elapsed: 6.11s
# Discriminator Cost: 0.5788 (Real: 0.7033 + Fake: 0.4544) Generator Cost: 1.2887
# Epoch 96/100 Time Elapsed: 5.84s
# Discriminator Cost: 0.5791 (Real: 0.7035 + Fake: 0.4546) Generator Cost: 1.2883
# Epoch 97/100 Time Elapsed: 5.77s
# Discriminator Cost: 0.5797 (Real: 0.7043 + Fake: 0.4552) Generator Cost: 1.2877
# Epoch 98/100 Time Elapsed: 6.11s
# Discriminator Cost: 0.5786 (Real: 0.7029 + Fake: 0.4543) Generator Cost: 1.2916
# Epoch 99/100 Time Elapsed: 6.29s
# Discriminator Cost: 0.5802 (Real: 0.7045 + Fake: 0.4559) Generator Cost: 1.2887
# Epoch 100/100 Time Elapsed: 5.84s
# Discriminator Cost: 0.5817 (Real: 0.7064 + Fake: 0.4570) Generator Cost: 1.2842

# %%
show_graphs(costs_history)

# %%
show_save_samples(sample_images_generated, save=True, gif_frame_duration=0.3)
