# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import imageio
from tensorflow.examples.tutorials.mnist import input_data
os.environ['CUDA_VISIBLE_DEVICES'] = '4'
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
"""
Compute the time elapsed
"""
def tic():
    global tic_time
    tic_time = time.time()
    
def toc():
    return time.time() - tic_time

# %%
"""
Load MNIST data
Return: all 70000(train + val + test) images
"""
def load_data():
    mnist = input_data.read_data_sets('MNIST_data/')
    images = np.append(np.append(mnist.train.images, mnist.validation.images, axis=0), mnist.test.images, axis=0)
    return images #shape = (70000, 784)

# %%
"""
Define the Generator
"""
def generator(noises_input, n_1, n_2, n_3, n_out):
    with tf.variable_scope('generator'):
        Z1 = tf.contrib.layers.fully_connected(noises_input, n_1, activation_fn=None, scope='Z1')
        A1 = tf.nn.leaky_relu(Z1, name='A1')
        Z2 = tf.contrib.layers.fully_connected(A1, n_2, activation_fn=None, scope='Z2')
        A2 = tf.nn.leaky_relu(Z2, name='A2')
        Z3 = tf.contrib.layers.fully_connected(A2, n_3, activation_fn=None, scope='Z3')
        A3 = tf.nn.leaky_relu(Z3, name='A3')
        Z_out = tf.contrib.layers.fully_connected(A3, n_out, activation_fn=None, scope='Z_out')
        A_out = tf.nn.tanh(Z_out, name='A_out')
    return A_out

# %%
"""
Define the Discriminator
"""
def discriminator(images_input, n_1, n_2, n_3, n_out, reuse=False):
    with tf.variable_scope('discriminator', reuse=reuse):
        Z1 = tf.contrib.layers.fully_connected(images_input, n_1, activation_fn=None, scope='Z1')
        A1 = tf.nn.leaky_relu(Z1, name='A1')
        A1_dropout = tf.nn.dropout(A1, 0.7, name='A1_dropout')
        Z2 = tf.contrib.layers.fully_connected(A1_dropout, n_2, activation_fn=None, scope='Z2')
        A2 = tf.nn.leaky_relu(Z2, name='A2')
        A2_dropout = tf.nn.dropout(A2, 0.7, name='A2_dropout')
        Z3 = tf.contrib.layers.fully_connected(A2_dropout, n_3, activation_fn=None, scope='Z3')
        A3 = tf.nn.leaky_relu(Z3, name='A3')
        A3_dropout = tf.nn.dropout(A3, 0.7, name='A3_dropout')
        Z_out = tf.contrib.layers.fully_connected(A3_dropout, n_out, activation_fn=None, scope='Z_out')
    return Z_out

# %%
"""
Define and Train Generative Adversarial Networks(GANs) Model
Return: history of costs(both generator and discriminator) 
        samples generated in each epoch
"""
def MNIST_GAN(hyperparams):
    tf.reset_default_graph()
    #Load data#
    mnist_images = load_data() * 2 - 1
    
    #Hyperparameters settings and properties#
    noise_size = hyperparams['noise_size']
    batch_size = hyperparams['batch_size']
    epoch = hyperparams['epoch']
    generator_n_1 = hyperparams['generator_n_1']
    generator_n_2 = hyperparams['generator_n_2']
    generator_n_3 = hyperparams['generator_n_3']
    generator_n_out = hyperparams['generator_n_out']
    discriminator_n_1 = hyperparams['discriminator_n_1']
    discriminator_n_2 = hyperparams['discriminator_n_2']
    discriminator_n_3 = hyperparams['discriminator_n_3']
    discriminator_n_out = hyperparams['discriminator_n_out']
    gen_learning_rate = hyperparams['gen_learning_rate']
    dis_learning_rate = hyperparams['dis_learning_rate']
    adam_beta1 = hyperparams['adam_beta1']
    sample_size = hyperparams['sample_size']
    data_size = mnist_images.shape[0]
    image_size = mnist_images.shape[1]
    total_batches = np.ceil(data_size / batch_size).astype(np.int32)
    
    #Define placeholders#
    real_images = tf.placeholder(tf.float32, (None, image_size), name='real_images')
    noises_input = tf.placeholder(tf.float32, (None, noise_size), name='noises_input')
    
    #Define the outputs of generator and discriminator#
    fake_images = generator(noises_input, generator_n_1, generator_n_2, generator_n_3, generator_n_out)
    real_logits = discriminator(real_images, discriminator_n_1, discriminator_n_2, discriminator_n_3, discriminator_n_out)
    fake_logits = discriminator(fake_images, discriminator_n_1, discriminator_n_2, discriminator_n_3, discriminator_n_out, reuse=True)
    
    #Define costs of discriminator(fake and real data) and generator#
    dis_real_cost = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=real_logits, labels=tf.ones_like(real_logits)))
    dis_fake_cost = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logits, labels=tf.zeros_like(fake_logits)))
    dis_cost = tf.divide(tf.add(dis_real_cost, dis_fake_cost), 2)
    gen_cost = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logits, labels=tf.ones_like(fake_logits)))
    
    #Define the optimization#
    trainable_vars = tf.trainable_variables()
    gen_vars = [var for var in trainable_vars if var.name.startswith('generator')]
    dis_vars = [var for var in trainable_vars if var.name.startswith('discriminator')]
    gen_optimize = tf.train.AdamOptimizer(learning_rate=gen_learning_rate, beta1=adam_beta1, name='gen_optimize').minimize(gen_cost, var_list=gen_vars)
    dis_optimize = tf.train.AdamOptimizer(learning_rate=dis_learning_rate, beta1=adam_beta1, name='dis_optimize').minimize(dis_cost, var_list=dis_vars)
    
    #Training#
    costs_history = []
    sample_images_generated = np.empty((0, sample_size, image_size))
    sample_noises_input = np.random.uniform(low=-1, high=1, size=(sample_size, noise_size))
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(epoch):
            tic()
            dis_cost_real_epoch = 0.
            dis_cost_fake_epoch = 0.
            dis_cost_epoch = 0.
            gen_cost_epoch = 0.
            for j in range(total_batches):
                index_front = j * batch_size
                index_end = (j + 1) * batch_size if (j + 1) * batch_size < data_size else data_size
                images_batch = mnist_images[index_front:index_end].reshape(-1, image_size)
                noises_batch = np.random.uniform(low=-1, high=1, size=(index_end - index_front, noise_size))
                _, dis_cost_real_iter, dis_cost_fake_iter, dis_cost_iter = sess.run([dis_optimize, dis_real_cost, dis_fake_cost, dis_cost], feed_dict={real_images:images_batch, noises_input:noises_batch})
                _, gen_cost_iter = sess.run([gen_optimize, gen_cost], feed_dict={noises_input:noises_batch})
                dis_cost_real_epoch += dis_cost_real_iter / data_size
                dis_cost_fake_epoch += dis_cost_fake_iter / data_size
                dis_cost_epoch += dis_cost_iter / data_size
                gen_cost_epoch += gen_cost_iter / data_size
            costs_history.append((dis_cost_real_epoch, dis_cost_fake_epoch, dis_cost_epoch, gen_cost_epoch))
            sample_images_generated_epoch = sess.run(fake_images, feed_dict={noises_input:sample_noises_input}).reshape(1, -1, image_size)
            sample_images_generated = np.append(sample_images_generated, sample_images_generated_epoch, axis=0)
            print('Epoch {}/{} Time Elapsed: {:.2f}s'.format(i + 1, epoch, toc()))
            print('Discriminator Cost: {:.4f} (Real: {:.4f} + Fake: {:.4f}) Generator Cost: {:.4f}'.format(dis_cost_epoch, dis_cost_real_epoch, dis_cost_fake_epoch, gen_cost_epoch))
        return costs_history, sample_images_generated

# %%
"""
Show graphs of costs of discriminator and generator
"""
def show_graphs(costs_history):
    costs = np.array(costs_history).T
    plt.figure(figsize=(20, 10))
    plt.ylabel('Cost')
    plt.xlabel('Epoch')
    plt.title('Cost - Epoch')
    plt.plot(costs[0], label='Discriminator Real Cost')
    plt.plot(costs[1], label='Discriminator Fake Cost')
    plt.plot(costs[2], label='Discriminator Total Cost')
    plt.plot(costs[3], label='Generator Cost')
    plt.legend(loc='best')
    plt.show()

# %%
"""
Show and save samples
Variables: 
    sample_images_generated shape: (num of epochs, num of samples in each epoch, num of rows of image, num of column of image)
    save: True if want to save the figures(pngs and gifs)
    folder_name: create the folder if not exists, save figures to the specific folder
"""
def show_save_samples(sample_images_generated, save=False, folder_name='MNIST_GAN_samples', gif_frame_duration=0.25):
    #Scale images to the range of [0, 1]#
    sample_images_generated = (sample_images_generated + 1) / 2
    
    #Create folder if not exists#
    if save and not os.path.exists('./{}'.format(folder_name)):
        os.mkdir(folder_name)
        
    #Parameters#
    epochs = sample_images_generated.shape[0]
    num_sample_each_epoch = sample_images_generated.shape[1]
    
    #Output and save figures#
    for i in range(epochs):
        plt.figure(figsize=(2 * num_sample_each_epoch, 5))
        for j in range(num_sample_each_epoch):
            plt.subplot(1, num_sample_each_epoch, j + 1)
            plt.axis('off')
            plt.imshow(sample_images_generated[i, j].reshape(28, 28), cmap='gray')    
        plt.text(-169, 40, 'Epoch {}'.format(i + 1), fontsize=25) #adjust the text location
        if save:
            plt.savefig('./{}/{}.png'.format(folder_name, i + 1))
        plt.show()
        
    #Make GIF#
    if save:
        gif_frames = []
        for i in range(epochs):
            gif_frames.append(imageio.imread('./{}/{}.png'.format(folder_name, i + 1)))
        imageio.mimsave('./{}/evolution.gif'.format(folder_name), gif_frames, duration=gif_frame_duration)

# %%
"""
Define the hyperparameters
"""
hyperparams={
    'noise_size': 100,
    'batch_size': 128,
    'epoch': 100,
    'generator_n_1': 256,
    'generator_n_2': 512,
    'generator_n_3': 1024,
    'generator_n_out': 784,
    'discriminator_n_1': 1024,
    'discriminator_n_2': 512,
    'discriminator_n_3': 256,
    'discriminator_n_out': 1,
    'gen_learning_rate': 0.0001,
    'dis_learning_rate': 0.0001,
    'adam_beta1': 0.5,
    'sample_size': 10
}
costs_history, sample_images_generated = MNIST_GAN(hyperparams)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Epoch 1/100 Time Elapsed: 5.06s
# Discriminator Cost: 0.3509 (Real: 0.1668 + Fake: 0.5351) Generator Cost: 1.6620
# Epoch 2/100 Time Elapsed: 4.55s
# Discriminator Cost: 0.2407 (Real: 0.2269 + Fake: 0.2546) Generator Cost: 3.1024
# Epoch 3/100 Time Elapsed: 4.78s
# Discriminator Cost: 0.2404 (Real: 0.2571 + Fake: 0.2237) Generator Cost: 3.2393
# Epoch 4/100 Time Elapsed: 4.62s
# Discriminator Cost: 0.2078 (Real: 0.2395 + Fake: 0.1761) Generator Cost: 3.1729
# Epoch 5/100 Time Elapsed: 4.42s
# Discriminator Cost: 0.2078 (Real: 0.2520 + Fake: 0.1635) Generator Cost: 2.8606
# Epoch 6/100 Time Elapsed: 4.64s
# Discriminator Cost: 0.2106 (Real: 0.2594 + Fake: 0.1619) Generator Cost: 2.7754
# Epoch 7/100 Time Elapsed: 4.57s
# Discriminator Cost: 0.2371 (Real: 0.2822 + Fake: 0.1920) Generator Cost: 2.6243
# Epoch 8/100 Time Elapsed: 4.67s
# Discriminator Cost: 0.2757 (Real: 0.3148 + Fake: 0.2366) Generator Cost: 2.4529
# Epoch 9/100 Time Elapsed: 4.64s
# Discriminator Cost: 0.3127 (Real: 0.3448 + Fake: 0.2806) Generator Cost: 2.3151
# Epoch 10/100 Time Elapsed: 4.79s
# Discriminator Cost: 0.3470 (Real: 0.3745 + Fake: 0.3195) Generator Cost: 2.1121
# Epoch 11/100 Time Elapsed: 4.82s
# Discriminator Cost: 0.3686 (Real: 0.3964 + Fake: 0.3407) Generator Cost: 2.0045
# Epoch 12/100 Time Elapsed: 4.86s
# Discriminator Cost: 0.3933 (Real: 0.4170 + Fake: 0.3696) Generator Cost: 1.8753
# Epoch 13/100 Time Elapsed: 4.83s
# Discriminator Cost: 0.4116 (Real: 0.4336 + Fake: 0.3896) Generator Cost: 1.7656
# Epoch 14/100 Time Elapsed: 4.64s
# Discriminator Cost: 0.4213 (Real: 0.4411 + Fake: 0.4014) Generator Cost: 1.7217
# Epoch 15/100 Time Elapsed: 4.64s
# Discriminator Cost: 0.4283 (Real: 0.4483 + Fake: 0.4082) Generator Cost: 1.6698
# Epoch 16/100 Time Elapsed: 4.68s
# Discriminator Cost: 0.4403 (Real: 0.4596 + Fake: 0.4210) Generator Cost: 1.5993
# Epoch 17/100 Time Elapsed: 4.63s
# Discriminator Cost: 0.4569 (Real: 0.4763 + Fake: 0.4374) Generator Cost: 1.5363
# Epoch 18/100 Time Elapsed: 4.53s
# Discriminator Cost: 0.4633 (Real: 0.4815 + Fake: 0.4451) Generator Cost: 1.5037
# Epoch 19/100 Time Elapsed: 4.50s
# Discriminator Cost: 0.4607 (Real: 0.4786 + Fake: 0.4429) Generator Cost: 1.5160
# Epoch 20/100 Time Elapsed: 4.50s
# Discriminator Cost: 0.4769 (Real: 0.4943 + Fake: 0.4595) Generator Cost: 1.4673
# Epoch 21/100 Time Elapsed: 4.69s
# Discriminator Cost: 0.4767 (Real: 0.4940 + Fake: 0.4594) Generator Cost: 1.4418
# Epoch 22/100 Time Elapsed: 4.78s
# Discriminator Cost: 0.4810 (Real: 0.4989 + Fake: 0.4632) Generator Cost: 1.4301
# Epoch 23/100 Time Elapsed: 4.59s
# Discriminator Cost: 0.4821 (Real: 0.4982 + Fake: 0.4660) Generator Cost: 1.4249
# Epoch 24/100 Time Elapsed: 4.69s
# Discriminator Cost: 0.4854 (Real: 0.5018 + Fake: 0.4691) Generator Cost: 1.4173
# Epoch 25/100 Time Elapsed: 4.59s
# Discriminator Cost: 0.4928 (Real: 0.5091 + Fake: 0.4766) Generator Cost: 1.3894
# Epoch 26/100 Time Elapsed: 4.75s
# Discriminator Cost: 0.4940 (Real: 0.5104 + Fake: 0.4775) Generator Cost: 1.3749
# Epoch 27/100 Time Elapsed: 4.85s
# Discriminator Cost: 0.5056 (Real: 0.5227 + Fake: 0.4885) Generator Cost: 1.3321
# Epoch 28/100 Time Elapsed: 4.67s
# Discriminator Cost: 0.5058 (Real: 0.5209 + Fake: 0.4907) Generator Cost: 1.3299
# Epoch 29/100 Time Elapsed: 4.44s
# Discriminator Cost: 0.5059 (Real: 0.5205 + Fake: 0.4914) Generator Cost: 1.3333
# Epoch 30/100 Time Elapsed: 4.79s
# Discriminator Cost: 0.5075 (Real: 0.5232 + Fake: 0.4918) Generator Cost: 1.3288
# Epoch 31/100 Time Elapsed: 4.43s
# Discriminator Cost: 0.5116 (Real: 0.5268 + Fake: 0.4965) Generator Cost: 1.3146
# Epoch 32/100 Time Elapsed: 4.59s
# Discriminator Cost: 0.5151 (Real: 0.5302 + Fake: 0.4999) Generator Cost: 1.3010
# Epoch 33/100 Time Elapsed: 4.49s
# Discriminator Cost: 0.5163 (Real: 0.5319 + Fake: 0.5008) Generator Cost: 1.2959
# Epoch 34/100 Time Elapsed: 4.45s
# Discriminator Cost: 0.5222 (Real: 0.5367 + Fake: 0.5076) Generator Cost: 1.2710
# Epoch 35/100 Time Elapsed: 4.69s
# Discriminator Cost: 0.5288 (Real: 0.5426 + Fake: 0.5150) Generator Cost: 1.2603
# Epoch 36/100 Time Elapsed: 4.64s
# Discriminator Cost: 0.5282 (Real: 0.5430 + Fake: 0.5134) Generator Cost: 1.2579
# Epoch 37/100 Time Elapsed: 4.57s
# Discriminator Cost: 0.5322 (Real: 0.5457 + Fake: 0.5186) Generator Cost: 1.2415
# Epoch 38/100 Time Elapsed: 4.63s
# Discriminator Cost: 0.5352 (Real: 0.5486 + Fake: 0.5218) Generator Cost: 1.2325
# Epoch 39/100 Time Elapsed: 4.77s
# Discriminator Cost: 0.5338 (Real: 0.5468 + Fake: 0.5207) Generator Cost: 1.2344
# Epoch 40/100 Time Elapsed: 4.65s
# Discriminator Cost: 0.5373 (Real: 0.5511 + Fake: 0.5235) Generator Cost: 1.2307
# Epoch 41/100 Time Elapsed: 4.29s
# Discriminator Cost: 0.5391 (Real: 0.5515 + Fake: 0.5267) Generator Cost: 1.2199
# Epoch 42/100 Time Elapsed: 4.45s
# Discriminator Cost: 0.5410 (Real: 0.5532 + Fake: 0.5289) Generator Cost: 1.2189
# Epoch 43/100 Time Elapsed: 4.74s
# Discriminator Cost: 0.5390 (Real: 0.5514 + Fake: 0.5266) Generator Cost: 1.2182
# Epoch 44/100 Time Elapsed: 4.55s
# Discriminator Cost: 0.5452 (Real: 0.5572 + Fake: 0.5332) Generator Cost: 1.2042
# Epoch 45/100 Time Elapsed: 4.75s
# Discriminator Cost: 0.5430 (Real: 0.5547 + Fake: 0.5313) Generator Cost: 1.2023
# Epoch 46/100 Time Elapsed: 4.73s
# Discriminator Cost: 0.5431 (Real: 0.5551 + Fake: 0.5311) Generator Cost: 1.2022
# Epoch 47/100 Time Elapsed: 4.55s
# Discriminator Cost: 0.5478 (Real: 0.5603 + Fake: 0.5352) Generator Cost: 1.1927
# Epoch 48/100 Time Elapsed: 4.60s
# Discriminator Cost: 0.5469 (Real: 0.5579 + Fake: 0.5360) Generator Cost: 1.1901
# Epoch 49/100 Time Elapsed: 4.52s
# Discriminator Cost: 0.5477 (Real: 0.5601 + Fake: 0.5353) Generator Cost: 1.1951
# Epoch 50/100 Time Elapsed: 4.71s
# Discriminator Cost: 0.5485 (Real: 0.5598 + Fake: 0.5372) Generator Cost: 1.1944
# Epoch 51/100 Time Elapsed: 4.62s
# Discriminator Cost: 0.5504 (Real: 0.5616 + Fake: 0.5392) Generator Cost: 1.1901
# Epoch 52/100 Time Elapsed: 4.84s
# Discriminator Cost: 0.5495 (Real: 0.5611 + Fake: 0.5378) Generator Cost: 1.1868
# Epoch 53/100 Time Elapsed: 4.59s
# Discriminator Cost: 0.5507 (Real: 0.5612 + Fake: 0.5402) Generator Cost: 1.1845
# Epoch 54/100 Time Elapsed: 4.70s
# Discriminator Cost: 0.5538 (Real: 0.5654 + Fake: 0.5421) Generator Cost: 1.1746
# Epoch 55/100 Time Elapsed: 4.76s
# Discriminator Cost: 0.5529 (Real: 0.5642 + Fake: 0.5416) Generator Cost: 1.1735
# Epoch 56/100 Time Elapsed: 4.91s
# Discriminator Cost: 0.5536 (Real: 0.5651 + Fake: 0.5421) Generator Cost: 1.1765
# Epoch 57/100 Time Elapsed: 4.79s
# Discriminator Cost: 0.5553 (Real: 0.5663 + Fake: 0.5443) Generator Cost: 1.1692
# Epoch 58/100 Time Elapsed: 4.67s
# Discriminator Cost: 0.5570 (Real: 0.5684 + Fake: 0.5456) Generator Cost: 1.1660
# Epoch 59/100 Time Elapsed: 4.61s
# Discriminator Cost: 0.5569 (Real: 0.5680 + Fake: 0.5458) Generator Cost: 1.1681
# Epoch 60/100 Time Elapsed: 4.52s
# Discriminator Cost: 0.5579 (Real: 0.5673 + Fake: 0.5484) Generator Cost: 1.1580
# Epoch 61/100 Time Elapsed: 4.84s
# Discriminator Cost: 0.5598 (Real: 0.5717 + Fake: 0.5480) Generator Cost: 1.1613
# Epoch 62/100 Time Elapsed: 4.60s
# Discriminator Cost: 0.5580 (Real: 0.5688 + Fake: 0.5473) Generator Cost: 1.1572
# Epoch 63/100 Time Elapsed: 4.40s
# Discriminator Cost: 0.5575 (Real: 0.5677 + Fake: 0.5473) Generator Cost: 1.1605
# Epoch 64/100 Time Elapsed: 4.74s
# Discriminator Cost: 0.5597 (Real: 0.5714 + Fake: 0.5480) Generator Cost: 1.1492
# Epoch 65/100 Time Elapsed: 4.71s
# Discriminator Cost: 0.5604 (Real: 0.5709 + Fake: 0.5499) Generator Cost: 1.1507
# Epoch 66/100 Time Elapsed: 4.77s
# Discriminator Cost: 0.5625 (Real: 0.5733 + Fake: 0.5517) Generator Cost: 1.1476
# Epoch 67/100 Time Elapsed: 4.73s
# Discriminator Cost: 0.5612 (Real: 0.5712 + Fake: 0.5511) Generator Cost: 1.1466
# Epoch 68/100 Time Elapsed: 4.75s
# Discriminator Cost: 0.5636 (Real: 0.5745 + Fake: 0.5527) Generator Cost: 1.1410
# Epoch 69/100 Time Elapsed: 4.91s
# Discriminator Cost: 0.5639 (Real: 0.5746 + Fake: 0.5531) Generator Cost: 1.1328
# Epoch 70/100 Time Elapsed: 4.68s
# Discriminator Cost: 0.5645 (Real: 0.5753 + Fake: 0.5537) Generator Cost: 1.1324
# Epoch 71/100 Time Elapsed: 4.73s
# Discriminator Cost: 0.5648 (Real: 0.5759 + Fake: 0.5536) Generator Cost: 1.1282
# Epoch 72/100 Time Elapsed: 4.58s
# Discriminator Cost: 0.5640 (Real: 0.5748 + Fake: 0.5531) Generator Cost: 1.1392
# Epoch 73/100 Time Elapsed: 4.70s
# Discriminator Cost: 0.5651 (Real: 0.5750 + Fake: 0.5552) Generator Cost: 1.1321
# Epoch 74/100 Time Elapsed: 4.71s
# Discriminator Cost: 0.5663 (Real: 0.5768 + Fake: 0.5558) Generator Cost: 1.1328
# Epoch 75/100 Time Elapsed: 4.75s
# Discriminator Cost: 0.5650 (Real: 0.5746 + Fake: 0.5554) Generator Cost: 1.1297
# Epoch 76/100 Time Elapsed: 4.75s
# Discriminator Cost: 0.5659 (Real: 0.5763 + Fake: 0.5556) Generator Cost: 1.1338
# Epoch 77/100 Time Elapsed: 4.55s
# Discriminator Cost: 0.5660 (Real: 0.5758 + Fake: 0.5562) Generator Cost: 1.1291
# Epoch 78/100 Time Elapsed: 4.63s
# Discriminator Cost: 0.5671 (Real: 0.5777 + Fake: 0.5565) Generator Cost: 1.1261
# Epoch 79/100 Time Elapsed: 4.69s
# Discriminator Cost: 0.5675 (Real: 0.5772 + Fake: 0.5578) Generator Cost: 1.1274
# Epoch 80/100 Time Elapsed: 4.33s
# Discriminator Cost: 0.5692 (Real: 0.5798 + Fake: 0.5586) Generator Cost: 1.1217
# Epoch 81/100 Time Elapsed: 4.85s
# Discriminator Cost: 0.5677 (Real: 0.5780 + Fake: 0.5574) Generator Cost: 1.1214
# Epoch 82/100 Time Elapsed: 4.86s
# Discriminator Cost: 0.5681 (Real: 0.5787 + Fake: 0.5575) Generator Cost: 1.1282
# Epoch 83/100 Time Elapsed: 4.62s
# Discriminator Cost: 0.5696 (Real: 0.5798 + Fake: 0.5595) Generator Cost: 1.1255
# Epoch 84/100 Time Elapsed: 4.55s
# Discriminator Cost: 0.5690 (Real: 0.5781 + Fake: 0.5598) Generator Cost: 1.1189
# Epoch 85/100 Time Elapsed: 4.88s
# Discriminator Cost: 0.5712 (Real: 0.5821 + Fake: 0.5603) Generator Cost: 1.1130
# Epoch 86/100 Time Elapsed: 4.46s
# Discriminator Cost: 0.5691 (Real: 0.5797 + Fake: 0.5585) Generator Cost: 1.1169
# Epoch 87/100 Time Elapsed: 4.60s
# Discriminator Cost: 0.5718 (Real: 0.5817 + Fake: 0.5619) Generator Cost: 1.1144
# Epoch 88/100 Time Elapsed: 4.77s
# Discriminator Cost: 0.5701 (Real: 0.5808 + Fake: 0.5594) Generator Cost: 1.1152
# Epoch 89/100 Time Elapsed: 4.75s
# Discriminator Cost: 0.5717 (Real: 0.5825 + Fake: 0.5609) Generator Cost: 1.1075
# Epoch 90/100 Time Elapsed: 4.59s
# Discriminator Cost: 0.5703 (Real: 0.5800 + Fake: 0.5607) Generator Cost: 1.1131
# Epoch 91/100 Time Elapsed: 4.82s
# Discriminator Cost: 0.5733 (Real: 0.5836 + Fake: 0.5630) Generator Cost: 1.1071
# Epoch 92/100 Time Elapsed: 4.66s
# Discriminator Cost: 0.5720 (Real: 0.5823 + Fake: 0.5618) Generator Cost: 1.1068
# Epoch 93/100 Time Elapsed: 4.62s
# Discriminator Cost: 0.5717 (Real: 0.5810 + Fake: 0.5623) Generator Cost: 1.1080
# Epoch 94/100 Time Elapsed: 4.66s
# Discriminator Cost: 0.5720 (Real: 0.5826 + Fake: 0.5613) Generator Cost: 1.1114
# Epoch 95/100 Time Elapsed: 4.32s
# Discriminator Cost: 0.5725 (Real: 0.5831 + Fake: 0.5619) Generator Cost: 1.1088
# Epoch 96/100 Time Elapsed: 4.79s
# Discriminator Cost: 0.5722 (Real: 0.5825 + Fake: 0.5620) Generator Cost: 1.1031
# Epoch 97/100 Time Elapsed: 4.68s
# Discriminator Cost: 0.5734 (Real: 0.5831 + Fake: 0.5638) Generator Cost: 1.1064
# Epoch 98/100 Time Elapsed: 4.87s
# Discriminator Cost: 0.5736 (Real: 0.5826 + Fake: 0.5646) Generator Cost: 1.1045
# Epoch 99/100 Time Elapsed: 4.82s
# Discriminator Cost: 0.5743 (Real: 0.5845 + Fake: 0.5640) Generator Cost: 1.0984
# Epoch 100/100 Time Elapsed: 4.61s
# Discriminator Cost: 0.5728 (Real: 0.5822 + Fake: 0.5634) Generator Cost: 1.1026

# %%
show_graphs(costs_history)

# %%
show_save_samples(sample_images_generated, save=True, gif_frame_duration=0.3)
