# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import imageio
from tensorflow.examples.tutorials.mnist import input_data
os.environ['CUDA_VISIBLE_DEVICES'] = '4'
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
"""
Compute the time elapsed
"""
def tic():
    global tic_time
    tic_time = time.time()
    
def toc():
    return time.time() - tic_time

# %%
"""
Load MNIST data
Return: all 70000(train + val + test) images
"""
def load_data():
    mnist = input_data.read_data_sets('MNIST_data/')
    images = np.append(np.append(mnist.train.images, mnist.validation.images, axis=0), mnist.test.images, axis=0)
    return images #shape = (70000, 784)

# %%
"""
Define the Generator
"""
def generator(noises_input, n_1, n_2, n_3, n_out):
    with tf.variable_scope('generator'):
        Z1 = tf.contrib.layers.fully_connected(noises_input, n_1, activation_fn=None, scope='Z1')
        A1 = tf.nn.leaky_relu(Z1, name='A1')
        Z2 = tf.contrib.layers.fully_connected(A1, n_2, activation_fn=None, scope='Z2')
        A2 = tf.nn.leaky_relu(Z2, name='A2')
        Z3 = tf.contrib.layers.fully_connected(A2, n_3, activation_fn=None, scope='Z3')
        A3 = tf.nn.leaky_relu(Z3, name='A3')
        Z_out = tf.contrib.layers.fully_connected(A3, n_out, activation_fn=None, scope='Z_out')
        A_out = tf.nn.tanh(Z_out, name='A_out')
    return A_out

# %%
"""
Define the Discriminator
"""
def discriminator(images_input, n_1, n_2, n_3, n_out, reuse=False):
    with tf.variable_scope('discriminator', reuse=reuse):
        Z1 = tf.contrib.layers.fully_connected(images_input, n_1, activation_fn=None, scope='Z1')
        A1 = tf.nn.leaky_relu(Z1, name='A1')
        A1_dropout = tf.nn.dropout(A1, 0.7, name='A1_dropout')
        Z2 = tf.contrib.layers.fully_connected(A1_dropout, n_2, activation_fn=None, scope='Z2')
        A2 = tf.nn.leaky_relu(Z2, name='A2')
        A2_dropout = tf.nn.dropout(A2, 0.7, name='A2_dropout')
        Z3 = tf.contrib.layers.fully_connected(A2_dropout, n_3, activation_fn=None, scope='Z3')
        A3 = tf.nn.leaky_relu(Z3, name='A3')
        A3_dropout = tf.nn.dropout(A3, 0.7, name='A3_dropout')
        Z_out = tf.contrib.layers.fully_connected(A3_dropout, n_out, activation_fn=None, scope='Z_out')
    return Z_out

# %%
"""
Define and Train Generative Adversarial Networks(GANs) Model
Return: history of costs(both generator and discriminator) 
        samples generated in each epoch
"""
def MNIST_GAN(hyperparams):
    tf.reset_default_graph()
    #Load data#
    mnist_images = load_data() * 2 - 1
    
    #Hyperparameters settings and properties#
    noise_size = hyperparams['noise_size']
    batch_size = hyperparams['batch_size']
    label_smooth = hyperparams['label_smooth']
    epoch = hyperparams['epoch']
    generator_n_1 = hyperparams['generator_n_1']
    generator_n_2 = hyperparams['generator_n_2']
    generator_n_3 = hyperparams['generator_n_3']
    generator_n_out = hyperparams['generator_n_out']
    discriminator_n_1 = hyperparams['discriminator_n_1']
    discriminator_n_2 = hyperparams['discriminator_n_2']
    discriminator_n_3 = hyperparams['discriminator_n_3']
    discriminator_n_out = hyperparams['discriminator_n_out']
    gen_learning_rate = hyperparams['gen_learning_rate']
    dis_learning_rate = hyperparams['dis_learning_rate']
    adam_beta1 = hyperparams['adam_beta1']
    sample_size = hyperparams['sample_size']
    data_size = mnist_images.shape[0]
    image_size = mnist_images.shape[1]
    total_batches = np.ceil(data_size / batch_size).astype(np.int32)
    
    #Define placeholders#
    real_images = tf.placeholder(tf.float32, (None, image_size), name='real_images')
    noises_input = tf.placeholder(tf.float32, (None, noise_size), name='noises_input')
    
    #Define the outputs of generator and discriminator#
    fake_images = generator(noises_input, generator_n_1, generator_n_2, generator_n_3, generator_n_out)
    real_logits = discriminator(real_images, discriminator_n_1, discriminator_n_2, discriminator_n_3, discriminator_n_out)
    fake_logits = discriminator(fake_images, discriminator_n_1, discriminator_n_2, discriminator_n_3, discriminator_n_out, reuse=True)
    
    #Define costs of discriminator(fake and real data) and generator#
    dis_real_cost = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=real_logits, labels=tf.subtract(tf.ones_like(real_logits), label_smooth)))
    dis_fake_cost = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logits, labels=tf.zeros_like(fake_logits)))
    dis_cost = tf.divide(tf.add(dis_real_cost, dis_fake_cost), 2)
    gen_cost = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logits, labels=tf.ones_like(fake_logits)))
    
    #Define the optimization#
    trainable_vars = tf.trainable_variables()
    gen_vars = [var for var in trainable_vars if var.name.startswith('generator')]
    dis_vars = [var for var in trainable_vars if var.name.startswith('discriminator')]
    gen_optimize = tf.train.AdamOptimizer(learning_rate=gen_learning_rate, beta1=adam_beta1, name='gen_optimize').minimize(gen_cost, var_list=gen_vars)
    dis_optimize = tf.train.AdamOptimizer(learning_rate=dis_learning_rate, beta1=adam_beta1, name='dis_optimize').minimize(dis_cost, var_list=dis_vars)
    
    #Training#
    costs_history = []
    sample_images_generated = np.empty((0, sample_size, image_size))
    sample_noises_input = np.random.uniform(low=-1, high=1, size=(sample_size, noise_size))
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(epoch):
            tic()
            dis_cost_real_epoch = 0.
            dis_cost_fake_epoch = 0.
            dis_cost_epoch = 0.
            gen_cost_epoch = 0.
            for j in range(total_batches):
                index_front = j * batch_size
                index_end = (j + 1) * batch_size if (j + 1) * batch_size < data_size else data_size
                images_batch = mnist_images[index_front:index_end].reshape(-1, image_size)
                noises_batch = np.random.uniform(low=-1, high=1, size=(index_end - index_front, noise_size))
                _, dis_cost_real_iter, dis_cost_fake_iter, dis_cost_iter = sess.run([dis_optimize, dis_real_cost, dis_fake_cost, dis_cost], feed_dict={real_images:images_batch, noises_input:noises_batch})
                _, gen_cost_iter = sess.run([gen_optimize, gen_cost], feed_dict={noises_input:noises_batch})
                dis_cost_real_epoch += dis_cost_real_iter / data_size
                dis_cost_fake_epoch += dis_cost_fake_iter / data_size
                dis_cost_epoch += dis_cost_iter / data_size
                gen_cost_epoch += gen_cost_iter / data_size
            costs_history.append((dis_cost_real_epoch, dis_cost_fake_epoch, dis_cost_epoch, gen_cost_epoch))
            sample_images_generated_epoch = sess.run(fake_images, feed_dict={noises_input:sample_noises_input}).reshape(1, -1, image_size)
            sample_images_generated = np.append(sample_images_generated, sample_images_generated_epoch, axis=0)
            print('Epoch {}/{} Time Elapsed: {:.2f}s'.format(i + 1, epoch, toc()))
            print('Discriminator Cost: {:.4f} (Real: {:.4f} + Fake: {:.4f}) Generator Cost: {:.4f}'.format(dis_cost_epoch, dis_cost_real_epoch, dis_cost_fake_epoch, gen_cost_epoch))
        return costs_history, sample_images_generated

# %%
"""
Show graphs of costs of discriminator and generator
"""
def show_graphs(costs_history):
    costs = np.array(costs_history).T
    plt.figure(figsize=(20, 10))
    plt.ylabel('Cost')
    plt.xlabel('Epoch')
    plt.title('Cost - Epoch')
    plt.plot(costs[0], label='Discriminator Real Cost')
    plt.plot(costs[1], label='Discriminator Fake Cost')
    plt.plot(costs[2], label='Discriminator Total Cost')
    plt.plot(costs[3], label='Generator Cost')
    plt.legend(loc='best')
    plt.show()

# %%
"""
Show and save samples
Variables: 
    sample_images_generated shape: (num of epochs, num of samples in each epoch, num of rows of image, num of column of image)
    save: True if want to save the figures(pngs and gifs)
    folder_name: create the folder if not exists, save figures to the specific folder
"""
def show_save_samples(sample_images_generated, save=False, folder_name='MNIST_GAN_samples', gif_frame_duration=0.25):
    #Scale images to the range of [0, 1]#
    sample_images_generated = (sample_images_generated + 1) / 2
    
    #Create folder if not exists#
    if save and not os.path.exists('./{}'.format(folder_name)):
        os.mkdir(folder_name)
        
    #Parameters#
    epochs = sample_images_generated.shape[0]
    num_sample_each_epoch = sample_images_generated.shape[1]
    
    #Output and save figures#
    for i in range(epochs):
        plt.figure(figsize=(2 * num_sample_each_epoch, 5))
        for j in range(num_sample_each_epoch):
            plt.subplot(1, num_sample_each_epoch, j + 1)
            plt.axis('off')
            plt.imshow(sample_images_generated[i, j].reshape(28, 28), cmap='gray')    
        plt.text(-169, 40, 'Epoch {}'.format(i + 1), fontsize=25) #adjust the text location
        if save:
            plt.savefig('./{}/{}.png'.format(folder_name, i + 1))
        plt.show()
        
    #Make GIF#
    if save:
        gif_frames = []
        for i in range(epochs):
            gif_frames.append(imageio.imread('./{}/{}.png'.format(folder_name, i + 1)))
        imageio.mimsave('./{}/evolution.gif'.format(folder_name), gif_frames, duration=gif_frame_duration)

# %%
"""
Define the hyperparameters
"""
hyperparams={
    'noise_size': 100,
    'batch_size': 128,
    'label_smooth': 0.1,
    'epoch': 100,
    'generator_n_1': 256,
    'generator_n_2': 512,
    'generator_n_3': 1024,
    'generator_n_out': 784,
    'discriminator_n_1': 1024,
    'discriminator_n_2': 512,
    'discriminator_n_3': 256,
    'discriminator_n_out': 1,
    'gen_learning_rate': 0.0001,
    'dis_learning_rate': 0.0001,
    'adam_beta1': 0.5,
    'sample_size': 10
}
costs_history, sample_images_generated = MNIST_GAN(hyperparams)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Epoch 1/100 Time Elapsed: 6.02s
# Discriminator Cost: 0.4731 (Real: 0.4464 + Fake: 0.4999) Generator Cost: 1.4063
# Epoch 2/100 Time Elapsed: 7.45s
# Discriminator Cost: 0.3860 (Real: 0.5313 + Fake: 0.2406) Generator Cost: 2.4851
# Epoch 3/100 Time Elapsed: 7.65s
# Discriminator Cost: 0.3670 (Real: 0.5467 + Fake: 0.1874) Generator Cost: 2.6930
# Epoch 4/100 Time Elapsed: 7.98s
# Discriminator Cost: 0.3607 (Real: 0.5449 + Fake: 0.1766) Generator Cost: 2.7561
# Epoch 5/100 Time Elapsed: 7.56s
# Discriminator Cost: 0.3599 (Real: 0.5449 + Fake: 0.1749) Generator Cost: 2.7399
# Epoch 6/100 Time Elapsed: 7.82s
# Discriminator Cost: 0.3651 (Real: 0.5479 + Fake: 0.1822) Generator Cost: 2.7250
# Epoch 7/100 Time Elapsed: 7.62s
# Discriminator Cost: 0.3766 (Real: 0.5557 + Fake: 0.1975) Generator Cost: 2.7055
# Epoch 8/100 Time Elapsed: 7.70s
# Discriminator Cost: 0.3968 (Real: 0.5685 + Fake: 0.2250) Generator Cost: 2.5452
# Epoch 9/100 Time Elapsed: 7.45s
# Discriminator Cost: 0.4056 (Real: 0.5724 + Fake: 0.2388) Generator Cost: 2.4903
# Epoch 10/100 Time Elapsed: 7.64s
# Discriminator Cost: 0.4196 (Real: 0.5834 + Fake: 0.2558) Generator Cost: 2.3701
# Epoch 11/100 Time Elapsed: 7.61s
# Discriminator Cost: 0.4350 (Real: 0.5952 + Fake: 0.2749) Generator Cost: 2.2014
# Epoch 12/100 Time Elapsed: 7.77s
# Discriminator Cost: 0.4511 (Real: 0.6087 + Fake: 0.2934) Generator Cost: 2.0754
# Epoch 13/100 Time Elapsed: 7.45s
# Discriminator Cost: 0.4584 (Real: 0.6154 + Fake: 0.3013) Generator Cost: 2.0279
# Epoch 14/100 Time Elapsed: 7.97s
# Discriminator Cost: 0.4685 (Real: 0.6236 + Fake: 0.3134) Generator Cost: 1.9361
# Epoch 15/100 Time Elapsed: 7.95s
# Discriminator Cost: 0.4826 (Real: 0.6317 + Fake: 0.3334) Generator Cost: 1.8221
# Epoch 16/100 Time Elapsed: 7.82s
# Discriminator Cost: 0.4891 (Real: 0.6388 + Fake: 0.3394) Generator Cost: 1.7879
# Epoch 17/100 Time Elapsed: 6.35s
# Discriminator Cost: 0.4947 (Real: 0.6415 + Fake: 0.3480) Generator Cost: 1.7445
# Epoch 18/100 Time Elapsed: 7.77s
# Discriminator Cost: 0.5010 (Real: 0.6459 + Fake: 0.3562) Generator Cost: 1.7014
# Epoch 19/100 Time Elapsed: 7.88s
# Discriminator Cost: 0.5011 (Real: 0.6461 + Fake: 0.3561) Generator Cost: 1.7145
# Epoch 20/100 Time Elapsed: 7.87s
# Discriminator Cost: 0.5055 (Real: 0.6486 + Fake: 0.3623) Generator Cost: 1.6878
# Epoch 21/100 Time Elapsed: 7.70s
# Discriminator Cost: 0.5094 (Real: 0.6508 + Fake: 0.3680) Generator Cost: 1.6653
# Epoch 22/100 Time Elapsed: 8.22s
# Discriminator Cost: 0.5143 (Real: 0.6548 + Fake: 0.3738) Generator Cost: 1.6382
# Epoch 23/100 Time Elapsed: 7.83s
# Discriminator Cost: 0.5158 (Real: 0.6571 + Fake: 0.3746) Generator Cost: 1.6282
# Epoch 24/100 Time Elapsed: 7.87s
# Discriminator Cost: 0.5161 (Real: 0.6578 + Fake: 0.3745) Generator Cost: 1.6163
# Epoch 25/100 Time Elapsed: 7.95s
# Discriminator Cost: 0.5218 (Real: 0.6615 + Fake: 0.3822) Generator Cost: 1.5904
# Epoch 26/100 Time Elapsed: 7.77s
# Discriminator Cost: 0.5245 (Real: 0.6635 + Fake: 0.3855) Generator Cost: 1.5682
# Epoch 27/100 Time Elapsed: 6.21s
# Discriminator Cost: 0.5283 (Real: 0.6664 + Fake: 0.3903) Generator Cost: 1.5519
# Epoch 28/100 Time Elapsed: 7.94s
# Discriminator Cost: 0.5301 (Real: 0.6676 + Fake: 0.3926) Generator Cost: 1.5509
# Epoch 29/100 Time Elapsed: 8.03s
# Discriminator Cost: 0.5323 (Real: 0.6693 + Fake: 0.3953) Generator Cost: 1.5284
# Epoch 30/100 Time Elapsed: 7.55s
# Discriminator Cost: 0.5338 (Real: 0.6711 + Fake: 0.3965) Generator Cost: 1.5318
# Epoch 31/100 Time Elapsed: 7.96s
# Discriminator Cost: 0.5363 (Real: 0.6719 + Fake: 0.4007) Generator Cost: 1.5099
# Epoch 32/100 Time Elapsed: 7.96s
# Discriminator Cost: 0.5367 (Real: 0.6730 + Fake: 0.4004) Generator Cost: 1.5163
# Epoch 33/100 Time Elapsed: 8.05s
# Discriminator Cost: 0.5397 (Real: 0.6750 + Fake: 0.4044) Generator Cost: 1.4965
# Epoch 34/100 Time Elapsed: 7.96s
# Discriminator Cost: 0.5411 (Real: 0.6753 + Fake: 0.4069) Generator Cost: 1.4818
# Epoch 35/100 Time Elapsed: 7.88s
# Discriminator Cost: 0.5417 (Real: 0.6766 + Fake: 0.4068) Generator Cost: 1.4814
# Epoch 36/100 Time Elapsed: 7.68s
# Discriminator Cost: 0.5447 (Real: 0.6789 + Fake: 0.4105) Generator Cost: 1.4715
# Epoch 37/100 Time Elapsed: 7.73s
# Discriminator Cost: 0.5450 (Real: 0.6790 + Fake: 0.4110) Generator Cost: 1.4693
# Epoch 38/100 Time Elapsed: 7.71s
# Discriminator Cost: 0.5459 (Real: 0.6798 + Fake: 0.4120) Generator Cost: 1.4635
# Epoch 39/100 Time Elapsed: 7.59s
# Discriminator Cost: 0.5498 (Real: 0.6821 + Fake: 0.4175) Generator Cost: 1.4452
# Epoch 40/100 Time Elapsed: 7.87s
# Discriminator Cost: 0.5515 (Real: 0.6840 + Fake: 0.4189) Generator Cost: 1.4365
# Epoch 41/100 Time Elapsed: 7.51s
# Discriminator Cost: 0.5530 (Real: 0.6846 + Fake: 0.4214) Generator Cost: 1.4276
# Epoch 42/100 Time Elapsed: 7.71s
# Discriminator Cost: 0.5553 (Real: 0.6848 + Fake: 0.4259) Generator Cost: 1.4210
# Epoch 43/100 Time Elapsed: 7.81s
# Discriminator Cost: 0.5589 (Real: 0.6876 + Fake: 0.4302) Generator Cost: 1.4037
# Epoch 44/100 Time Elapsed: 6.86s
# Discriminator Cost: 0.5585 (Real: 0.6878 + Fake: 0.4293) Generator Cost: 1.4060
# Epoch 45/100 Time Elapsed: 7.19s
# Discriminator Cost: 0.5612 (Real: 0.6891 + Fake: 0.4332) Generator Cost: 1.3944
# Epoch 46/100 Time Elapsed: 6.25s
# Discriminator Cost: 0.5615 (Real: 0.6901 + Fake: 0.4329) Generator Cost: 1.3877
# Epoch 47/100 Time Elapsed: 7.94s
# Discriminator Cost: 0.5617 (Real: 0.6900 + Fake: 0.4333) Generator Cost: 1.3882
# Epoch 48/100 Time Elapsed: 7.91s
# Discriminator Cost: 0.5617 (Real: 0.6897 + Fake: 0.4337) Generator Cost: 1.3914
# Epoch 49/100 Time Elapsed: 7.86s
# Discriminator Cost: 0.5637 (Real: 0.6912 + Fake: 0.4362) Generator Cost: 1.3843
# Epoch 50/100 Time Elapsed: 8.04s
# Discriminator Cost: 0.5669 (Real: 0.6936 + Fake: 0.4403) Generator Cost: 1.3640
# Epoch 51/100 Time Elapsed: 7.64s
# Discriminator Cost: 0.5662 (Real: 0.6930 + Fake: 0.4393) Generator Cost: 1.3653
# Epoch 52/100 Time Elapsed: 7.70s
# Discriminator Cost: 0.5675 (Real: 0.6940 + Fake: 0.4411) Generator Cost: 1.3638
# Epoch 53/100 Time Elapsed: 7.85s
# Discriminator Cost: 0.5686 (Real: 0.6955 + Fake: 0.4418) Generator Cost: 1.3541
# Epoch 54/100 Time Elapsed: 7.86s
# Discriminator Cost: 0.5674 (Real: 0.6941 + Fake: 0.4406) Generator Cost: 1.3574
# Epoch 55/100 Time Elapsed: 8.21s
# Discriminator Cost: 0.5698 (Real: 0.6955 + Fake: 0.4440) Generator Cost: 1.3502
# Epoch 56/100 Time Elapsed: 7.87s
# Discriminator Cost: 0.5717 (Real: 0.6968 + Fake: 0.4465) Generator Cost: 1.3393
# Epoch 57/100 Time Elapsed: 7.76s
# Discriminator Cost: 0.5706 (Real: 0.6966 + Fake: 0.4446) Generator Cost: 1.3424
# Epoch 58/100 Time Elapsed: 7.40s
# Discriminator Cost: 0.5718 (Real: 0.6968 + Fake: 0.4467) Generator Cost: 1.3395
# Epoch 59/100 Time Elapsed: 7.61s
# Discriminator Cost: 0.5716 (Real: 0.6961 + Fake: 0.4470) Generator Cost: 1.3361
# Epoch 60/100 Time Elapsed: 7.95s
# Discriminator Cost: 0.5729 (Real: 0.6977 + Fake: 0.4481) Generator Cost: 1.3306
# Epoch 61/100 Time Elapsed: 7.60s
# Discriminator Cost: 0.5732 (Real: 0.6979 + Fake: 0.4485) Generator Cost: 1.3299
# Epoch 62/100 Time Elapsed: 8.07s
# Discriminator Cost: 0.5747 (Real: 0.6985 + Fake: 0.4510) Generator Cost: 1.3300
# Epoch 63/100 Time Elapsed: 7.74s
# Discriminator Cost: 0.5754 (Real: 0.6990 + Fake: 0.4517) Generator Cost: 1.3246
# Epoch 64/100 Time Elapsed: 7.32s
# Discriminator Cost: 0.5768 (Real: 0.6998 + Fake: 0.4537) Generator Cost: 1.3162
# Epoch 65/100 Time Elapsed: 7.49s
# Discriminator Cost: 0.5769 (Real: 0.7003 + Fake: 0.4535) Generator Cost: 1.3155
# Epoch 66/100 Time Elapsed: 7.56s
# Discriminator Cost: 0.5773 (Real: 0.7005 + Fake: 0.4540) Generator Cost: 1.3165
# Epoch 67/100 Time Elapsed: 8.06s
# Discriminator Cost: 0.5798 (Real: 0.7029 + Fake: 0.4566) Generator Cost: 1.3064
# Epoch 68/100 Time Elapsed: 7.78s
# Discriminator Cost: 0.5778 (Real: 0.7004 + Fake: 0.4552) Generator Cost: 1.3108
# Epoch 69/100 Time Elapsed: 7.22s
# Discriminator Cost: 0.5794 (Real: 0.7016 + Fake: 0.4572) Generator Cost: 1.2978
# Epoch 70/100 Time Elapsed: 6.07s
# Discriminator Cost: 0.5794 (Real: 0.7022 + Fake: 0.4566) Generator Cost: 1.3101
# Epoch 71/100 Time Elapsed: 8.19s
# Discriminator Cost: 0.5811 (Real: 0.7036 + Fake: 0.4586) Generator Cost: 1.3005
# Epoch 72/100 Time Elapsed: 7.77s
# Discriminator Cost: 0.5788 (Real: 0.7010 + Fake: 0.4566) Generator Cost: 1.3007
# Epoch 73/100 Time Elapsed: 6.07s
# Discriminator Cost: 0.5806 (Real: 0.7029 + Fake: 0.4583) Generator Cost: 1.2925
# Epoch 74/100 Time Elapsed: 7.59s
# Discriminator Cost: 0.5804 (Real: 0.7026 + Fake: 0.4582) Generator Cost: 1.2990
# Epoch 75/100 Time Elapsed: 7.56s
# Discriminator Cost: 0.5791 (Real: 0.7015 + Fake: 0.4567) Generator Cost: 1.2973
# Epoch 76/100 Time Elapsed: 7.75s
# Discriminator Cost: 0.5816 (Real: 0.7032 + Fake: 0.4600) Generator Cost: 1.2927
# Epoch 77/100 Time Elapsed: 7.68s
# Discriminator Cost: 0.5810 (Real: 0.7028 + Fake: 0.4591) Generator Cost: 1.2919
# Epoch 78/100 Time Elapsed: 7.66s
# Discriminator Cost: 0.5828 (Real: 0.7043 + Fake: 0.4612) Generator Cost: 1.2771
# Epoch 79/100 Time Elapsed: 7.87s
# Discriminator Cost: 0.5810 (Real: 0.7030 + Fake: 0.4590) Generator Cost: 1.2873
# Epoch 80/100 Time Elapsed: 7.83s
# Discriminator Cost: 0.5834 (Real: 0.7051 + Fake: 0.4618) Generator Cost: 1.2837
# Epoch 81/100 Time Elapsed: 8.06s
# Discriminator Cost: 0.5833 (Real: 0.7045 + Fake: 0.4621) Generator Cost: 1.2728
# Epoch 82/100 Time Elapsed: 7.74s
# Discriminator Cost: 0.5852 (Real: 0.7062 + Fake: 0.4643) Generator Cost: 1.2765
# Epoch 83/100 Time Elapsed: 7.76s
# Discriminator Cost: 0.5853 (Real: 0.7061 + Fake: 0.4645) Generator Cost: 1.2705
# Epoch 84/100 Time Elapsed: 8.12s
# Discriminator Cost: 0.5847 (Real: 0.7057 + Fake: 0.4638) Generator Cost: 1.2712
# Epoch 85/100 Time Elapsed: 7.76s
# Discriminator Cost: 0.5844 (Real: 0.7054 + Fake: 0.4634) Generator Cost: 1.2768
# Epoch 86/100 Time Elapsed: 7.57s
# Discriminator Cost: 0.5867 (Real: 0.7071 + Fake: 0.4662) Generator Cost: 1.2669
# Epoch 87/100 Time Elapsed: 7.96s
# Discriminator Cost: 0.5870 (Real: 0.7078 + Fake: 0.4661) Generator Cost: 1.2657
# Epoch 88/100 Time Elapsed: 7.65s
# Discriminator Cost: 0.5853 (Real: 0.7061 + Fake: 0.4646) Generator Cost: 1.2633
# Epoch 89/100 Time Elapsed: 5.89s
# Discriminator Cost: 0.5875 (Real: 0.7078 + Fake: 0.4672) Generator Cost: 1.2616
# Epoch 90/100 Time Elapsed: 7.58s
# Discriminator Cost: 0.5868 (Real: 0.7068 + Fake: 0.4668) Generator Cost: 1.2642
# Epoch 91/100 Time Elapsed: 7.83s
# Discriminator Cost: 0.5887 (Real: 0.7093 + Fake: 0.4681) Generator Cost: 1.2524
# Epoch 92/100 Time Elapsed: 7.60s
# Discriminator Cost: 0.5875 (Real: 0.7076 + Fake: 0.4674) Generator Cost: 1.2619
# Epoch 93/100 Time Elapsed: 7.53s
# Discriminator Cost: 0.5892 (Real: 0.7093 + Fake: 0.4691) Generator Cost: 1.2527
# Epoch 94/100 Time Elapsed: 7.56s
# Discriminator Cost: 0.5883 (Real: 0.7076 + Fake: 0.4690) Generator Cost: 1.2542
# Epoch 95/100 Time Elapsed: 7.69s
# Discriminator Cost: 0.5882 (Real: 0.7081 + Fake: 0.4683) Generator Cost: 1.2523
# Epoch 96/100 Time Elapsed: 7.80s
# Discriminator Cost: 0.5903 (Real: 0.7094 + Fake: 0.4711) Generator Cost: 1.2450
# Epoch 97/100 Time Elapsed: 7.91s
# Discriminator Cost: 0.5905 (Real: 0.7101 + Fake: 0.4709) Generator Cost: 1.2512
# Epoch 98/100 Time Elapsed: 7.70s
# Discriminator Cost: 0.5908 (Real: 0.7101 + Fake: 0.4715) Generator Cost: 1.2496
# Epoch 99/100 Time Elapsed: 7.59s
# Discriminator Cost: 0.5884 (Real: 0.7080 + Fake: 0.4688) Generator Cost: 1.2519
# Epoch 100/100 Time Elapsed: 7.78s
# Discriminator Cost: 0.5905 (Real: 0.7093 + Fake: 0.4716) Generator Cost: 1.2415

# %%
show_graphs(costs_history)

# %%
show_save_samples(sample_images_generated, save=True, gif_frame_duration=0.3)
