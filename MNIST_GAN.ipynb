# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import imageio
from tensorflow.examples.tutorials.mnist import input_data
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
"""
Compute the time elapsed
"""
def tic():
    global tic_time
    tic_time = time.time()
    
def toc():
    return time.time() - tic_time

# %%
"""
Load MNIST data
Return: all 70000(train + val + test) images
"""
def load_data():
    mnist = input_data.read_data_sets('MNIST_data/')
    images = np.append(np.append(mnist.train.images, mnist.validation.images, axis=0), mnist.test.images, axis=0)
    return images #shape = (70000, 784)

# %%
"""
Define the Generator
"""
def generator(noises_input, n_1, n_2, n_3, n_out):
    with tf.variable_scope('generator'):
        Z1 = tf.contrib.layers.fully_connected(noises_input, n_1, activation_fn=None, scope='Z1')
        A1 = tf.nn.leaky_relu(Z1, name='A1')
        Z2 = tf.contrib.layers.fully_connected(A1, n_2, activation_fn=None, scope='Z2')
        A2 = tf.nn.leaky_relu(Z2, name='A2')
        Z3 = tf.contrib.layers.fully_connected(A2, n_3, activation_fn=None, scope='Z3')
        A3 = tf.nn.leaky_relu(Z3, name='A3')
        Z_out = tf.contrib.layers.fully_connected(A3, n_out, activation_fn=None, scope='Z_out')
        A_out = tf.nn.tanh(Z_out, name='A_out')
    return A_out

# %%
"""
Define the Discriminator
"""
def discriminator(images_input, n_1, n_2, n_3, n_out, reuse=False):
    with tf.variable_scope('discriminator', reuse=reuse):
        Z1 = tf.contrib.layers.fully_connected(images_input, n_1, activation_fn=None, scope='Z1')
        A1 = tf.nn.leaky_relu(Z1, name='A1')
        A1_dropout = tf.nn.dropout(A1, 0.7, name='A1_dropout')
        Z2 = tf.contrib.layers.fully_connected(A1_dropout, n_2, activation_fn=None, scope='Z2')
        A2 = tf.nn.leaky_relu(Z2, name='A2')
        A2_dropout = tf.nn.dropout(A2, 0.7, name='A2_dropout')
        Z3 = tf.contrib.layers.fully_connected(A2_dropout, n_3, activation_fn=None, scope='Z3')
        A3 = tf.nn.leaky_relu(Z3, name='A3')
        A3_dropout = tf.nn.dropout(A3, 0.7, name='A3_dropout')
        Z_out = tf.contrib.layers.fully_connected(A3_dropout, n_out, activation_fn=None, scope='Z_out')
    return Z_out

# %%
"""
Define and Train Generative Adversarial Networks(GANs) Model
Return: history of costs(both generator and discriminator) 
        samples generated in each epoch
"""
def MNIST_GAN(hyperparams):
    tf.reset_default_graph()
    
    #Load data#
    mnist_images = load_data() * 2 - 1
    
    #Hyperparameters settings and properties#
    noise_size = hyperparams['noise_size']
    batch_size = hyperparams['batch_size']
    label_smooth = hyperparams['label_smooth']
    epoch = hyperparams['epoch']
    generator_n_1 = hyperparams['generator_n_1']
    generator_n_2 = hyperparams['generator_n_2']
    generator_n_3 = hyperparams['generator_n_3']
    generator_n_out = hyperparams['generator_n_out']
    discriminator_n_1 = hyperparams['discriminator_n_1']
    discriminator_n_2 = hyperparams['discriminator_n_2']
    discriminator_n_3 = hyperparams['discriminator_n_3']
    discriminator_n_out = hyperparams['discriminator_n_out']
    gen_learning_rate = hyperparams['gen_learning_rate']
    dis_learning_rate = hyperparams['dis_learning_rate']
    adam_beta1 = hyperparams['adam_beta1']
    sample_size = hyperparams['sample_size']
    data_size = mnist_images.shape[0]
    image_size = mnist_images.shape[1]
    total_batches = np.ceil(data_size / batch_size).astype(np.int32)
    
    #Define placeholders#
    real_images = tf.placeholder(tf.float32, (None, image_size), name='real_images')
    noises_input = tf.placeholder(tf.float32, (None, noise_size), name='noises_input')
    
    #Define the outputs of generator and discriminator#
    fake_images = generator(noises_input, generator_n_1, generator_n_2, generator_n_3, generator_n_out)
    real_logits = discriminator(real_images, discriminator_n_1, discriminator_n_2, discriminator_n_3, discriminator_n_out)
    fake_logits = discriminator(fake_images, discriminator_n_1, discriminator_n_2, discriminator_n_3, discriminator_n_out, reuse=True)
    
    #Define costs of discriminator(fake and real data) and generator#
    dis_real_cost = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=real_logits, labels=tf.multiply(tf.ones_like(real_logits), (1. - label_smooth))))
    dis_fake_cost = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logits, labels=tf.zeros_like(fake_logits)))
    dis_cost = tf.divide(tf.add(dis_real_cost, dis_fake_cost), 2)
    gen_cost = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logits, labels=tf.ones_like(fake_logits)))
    
    #Define the optimization#
    trainable_vars = tf.trainable_variables()
    gen_vars = [var for var in trainable_vars if var.name.startswith('generator')]
    dis_vars = [var for var in trainable_vars if var.name.startswith('discriminator')]
    gen_optimize = tf.train.AdamOptimizer(learning_rate=gen_learning_rate, beta1=adam_beta1, name='gen_optimize').minimize(gen_cost, var_list=gen_vars)
    dis_optimize = tf.train.AdamOptimizer(learning_rate=dis_learning_rate, beta1=adam_beta1, name='dis_optimize').minimize(dis_cost, var_list=dis_vars)
    
    #Training#
    costs_history = []
    sample_images_generated = np.empty((0, sample_size, image_size))
    sample_noises_input = np.random.uniform(low=-1, high=1, size=(sample_size, noise_size))
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(epoch):
            tic()
            
            #Reset the accumulator#
            dis_cost_real_epoch = 0.
            dis_cost_fake_epoch = 0.
            dis_cost_epoch = 0.
            gen_cost_epoch = 0.
            for j in range(total_batches):
                
                #Retrieve the data batch need to be fed#
                index_front = j * batch_size
                index_end = (j + 1) * batch_size if (j + 1) * batch_size < data_size else data_size
                images_batch = mnist_images[index_front:index_end].reshape(-1, image_size)
                noises_batch = np.random.uniform(low=-1, high=1, size=(index_end - index_front, noise_size))
                
                #Update discriminator and generator#
                _, dis_cost_real_iter, dis_cost_fake_iter, dis_cost_iter = sess.run([dis_optimize, dis_real_cost, dis_fake_cost, dis_cost], feed_dict={real_images:images_batch, noises_input:noises_batch})
                _, gen_cost_iter = sess.run([gen_optimize, gen_cost], feed_dict={noises_input:noises_batch})
                
                #Compute and save the average(likely) cost in epoch and in iteration#
                dis_cost_real_epoch += dis_cost_real_iter / data_size
                dis_cost_fake_epoch += dis_cost_fake_iter / data_size
                dis_cost_epoch += dis_cost_iter / data_size
                gen_cost_epoch += gen_cost_iter / data_size
                dis_cost_real_iter /= (index_end - index_front)
                dis_cost_fake_iter /= (index_end - index_front)
                dis_cost_iter /= (index_end - index_front)
                gen_cost_iter /= (index_end - index_front)
                costs_history.append((dis_cost_real_iter, dis_cost_fake_iter, dis_cost_iter, gen_cost_iter))
            
            #Get sample image generated every epoch#
            sample_images_generated_epoch = sess.run(fake_images, feed_dict={noises_input:sample_noises_input}).reshape(1, -1, image_size)
            sample_images_generated = np.append(sample_images_generated, sample_images_generated_epoch, axis=0)
            
            #Print the state every epoch#
            print('Epoch {}/{} Time Elapsed: {:.2f}s'.format(i + 1, epoch, toc()))
            print('Discriminator Cost: {:.4f} (Real: {:.4f} + Fake: {:.4f}) Generator Cost: {:.4f}'.format(dis_cost_epoch, dis_cost_real_epoch, dis_cost_fake_epoch, gen_cost_epoch))
        return costs_history, sample_images_generated

# %%
"""
Show graphs of costs of discriminator and generator
"""
def show_graphs(costs_history):
    costs = np.array(costs_history).T
    plt.figure(figsize=(20, 10))
    plt.ylabel('Cost')
    plt.xlabel('Iteration')
    plt.title('Cost - Iteration')
    plt.plot(costs[0], label='Discriminator Real Cost')
    plt.plot(costs[1], label='Discriminator Fake Cost')
    plt.plot(costs[2], label='Discriminator Total Cost')
    plt.plot(costs[3], label='Generator Cost')
    plt.legend(loc='best')
    plt.show()

# %%
"""
Show and save samples
Variables: 
    sample_images_generated shape: (num of epochs, num of samples in each epoch, num of rows of image, num of column of image)
    save: True if want to save the figures(pngs and gifs)
    folder_name: create the folder if not exists, save figures to the specific folder
"""
def show_save_samples(sample_images_generated, save=False, folder_name='MNIST_GAN_samples', gif_frame_duration=0.25):
    #Scale images to the range of [0, 1]#
    sample_images_generated = (sample_images_generated + 1) / 2
    
    #Create folder if not exists#
    if save and not os.path.exists('./{}'.format(folder_name)):
        os.mkdir(folder_name)
        
    #Parameters#
    epochs = sample_images_generated.shape[0]
    num_sample_each_epoch = sample_images_generated.shape[1]
    
    #Output and save figures#
    for i in range(epochs):
        plt.figure(figsize=(2 * num_sample_each_epoch, 5))
        for j in range(num_sample_each_epoch):
            plt.subplot(1, num_sample_each_epoch, j + 1)
            plt.axis('off')
            plt.imshow(sample_images_generated[i, j].reshape(28, 28), cmap='gray')    
        plt.text(-169, 40, 'Epoch {}'.format(i + 1), fontsize=25) #adjust the text location
        if save:
            plt.savefig('./{}/{}.png'.format(folder_name, i + 1))
        plt.show()
        
    #Make GIF#
    if save:
        gif_frames = []
        for i in range(epochs):
            gif_frames.append(imageio.imread('./{}/{}.png'.format(folder_name, i + 1)))
        imageio.mimsave('./{}/evolution.gif'.format(folder_name), gif_frames, duration=gif_frame_duration)

# %%
"""
Define the hyperparameters
"""
hyperparams={
    'noise_size': 100,
    'batch_size': 128,
    'label_smooth': 0.1,
    'epoch': 100,
    'generator_n_1': 256,
    'generator_n_2': 512,
    'generator_n_3': 1024,
    'generator_n_out': 784,
    'discriminator_n_1': 1024,
    'discriminator_n_2': 512,
    'discriminator_n_3': 256,
    'discriminator_n_out': 1,
    'gen_learning_rate': 0.0001,
    'dis_learning_rate': 0.0001,
    'adam_beta1': 0.5,
    'sample_size': 10
}
costs_history, sample_images_generated = MNIST_GAN(hyperparams)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Epoch 1/100 Time Elapsed: 5.82s
# Discriminator Cost: 0.4658 (Real: 0.4453 + Fake: 0.4863) Generator Cost: 1.4494
# Epoch 2/100 Time Elapsed: 5.22s
# Discriminator Cost: 0.3943 (Real: 0.5379 + Fake: 0.2507) Generator Cost: 2.4582
# Epoch 3/100 Time Elapsed: 5.82s
# Discriminator Cost: 0.3670 (Real: 0.5460 + Fake: 0.1880) Generator Cost: 2.6508
# Epoch 4/100 Time Elapsed: 5.83s
# Discriminator Cost: 0.3492 (Real: 0.5426 + Fake: 0.1558) Generator Cost: 2.7751
# Epoch 5/100 Time Elapsed: 5.74s
# Discriminator Cost: 0.3542 (Real: 0.5414 + Fake: 0.1669) Generator Cost: 2.8131
# Epoch 6/100 Time Elapsed: 5.83s
# Discriminator Cost: 0.3755 (Real: 0.5563 + Fake: 0.1947) Generator Cost: 2.6795
# Epoch 7/100 Time Elapsed: 5.76s
# Discriminator Cost: 0.3838 (Real: 0.5596 + Fake: 0.2080) Generator Cost: 2.6174
# Epoch 8/100 Time Elapsed: 5.76s
# Discriminator Cost: 0.3920 (Real: 0.5631 + Fake: 0.2210) Generator Cost: 2.5690
# Epoch 9/100 Time Elapsed: 5.92s
# Discriminator Cost: 0.3864 (Real: 0.5588 + Fake: 0.2141) Generator Cost: 2.6531
# Epoch 10/100 Time Elapsed: 5.91s
# Discriminator Cost: 0.4076 (Real: 0.5760 + Fake: 0.2391) Generator Cost: 2.4417
# Epoch 11/100 Time Elapsed: 5.95s
# Discriminator Cost: 0.4206 (Real: 0.5882 + Fake: 0.2529) Generator Cost: 2.3206
# Epoch 12/100 Time Elapsed: 6.38s
# Discriminator Cost: 0.4453 (Real: 0.6035 + Fake: 0.2872) Generator Cost: 2.1313
# Epoch 13/100 Time Elapsed: 6.19s
# Discriminator Cost: 0.4707 (Real: 0.6232 + Fake: 0.3182) Generator Cost: 1.9516
# Epoch 14/100 Time Elapsed: 6.50s
# Discriminator Cost: 0.4827 (Real: 0.6308 + Fake: 0.3346) Generator Cost: 1.8657
# Epoch 15/100 Time Elapsed: 6.52s
# Discriminator Cost: 0.5049 (Real: 0.6482 + Fake: 0.3615) Generator Cost: 1.7297
# Epoch 16/100 Time Elapsed: 6.41s
# Discriminator Cost: 0.5059 (Real: 0.6470 + Fake: 0.3649) Generator Cost: 1.7084
# Epoch 17/100 Time Elapsed: 6.29s
# Discriminator Cost: 0.5189 (Real: 0.6564 + Fake: 0.3814) Generator Cost: 1.6365
# Epoch 18/100 Time Elapsed: 6.44s
# Discriminator Cost: 0.5160 (Real: 0.6551 + Fake: 0.3770) Generator Cost: 1.6343
# Epoch 19/100 Time Elapsed: 6.35s
# Discriminator Cost: 0.5220 (Real: 0.6605 + Fake: 0.3836) Generator Cost: 1.6092
# Epoch 20/100 Time Elapsed: 6.37s
# Discriminator Cost: 0.5273 (Real: 0.6645 + Fake: 0.3900) Generator Cost: 1.5690
# Epoch 21/100 Time Elapsed: 6.37s
# Discriminator Cost: 0.5334 (Real: 0.6693 + Fake: 0.3976) Generator Cost: 1.5313
# Epoch 22/100 Time Elapsed: 5.44s
# Discriminator Cost: 0.5358 (Real: 0.6720 + Fake: 0.3997) Generator Cost: 1.5131
# Epoch 23/100 Time Elapsed: 6.87s
# Discriminator Cost: 0.5412 (Real: 0.6744 + Fake: 0.4081) Generator Cost: 1.4918
# Epoch 24/100 Time Elapsed: 6.20s
# Discriminator Cost: 0.5471 (Real: 0.6794 + Fake: 0.4148) Generator Cost: 1.4703
# Epoch 25/100 Time Elapsed: 6.63s
# Discriminator Cost: 0.5482 (Real: 0.6801 + Fake: 0.4164) Generator Cost: 1.4574
# Epoch 26/100 Time Elapsed: 6.57s
# Discriminator Cost: 0.5516 (Real: 0.6826 + Fake: 0.4205) Generator Cost: 1.4357
# Epoch 27/100 Time Elapsed: 6.47s
# Discriminator Cost: 0.5543 (Real: 0.6846 + Fake: 0.4239) Generator Cost: 1.4206
# Epoch 28/100 Time Elapsed: 6.44s
# Discriminator Cost: 0.5555 (Real: 0.6841 + Fake: 0.4269) Generator Cost: 1.4150
# Epoch 29/100 Time Elapsed: 6.53s
# Discriminator Cost: 0.5569 (Real: 0.6847 + Fake: 0.4290) Generator Cost: 1.4109
# Epoch 30/100 Time Elapsed: 6.63s
# Discriminator Cost: 0.5600 (Real: 0.6872 + Fake: 0.4329) Generator Cost: 1.3966
# Epoch 31/100 Time Elapsed: 6.48s
# Discriminator Cost: 0.5609 (Real: 0.6878 + Fake: 0.4341) Generator Cost: 1.3927
# Epoch 32/100 Time Elapsed: 6.34s
# Discriminator Cost: 0.5632 (Real: 0.6900 + Fake: 0.4364) Generator Cost: 1.3805
# Epoch 33/100 Time Elapsed: 6.34s
# Discriminator Cost: 0.5656 (Real: 0.6910 + Fake: 0.4403) Generator Cost: 1.3668
# Epoch 34/100 Time Elapsed: 6.69s
# Discriminator Cost: 0.5671 (Real: 0.6932 + Fake: 0.4410) Generator Cost: 1.3677
# Epoch 35/100 Time Elapsed: 6.60s
# Discriminator Cost: 0.5692 (Real: 0.6934 + Fake: 0.4450) Generator Cost: 1.3588
# Epoch 36/100 Time Elapsed: 6.42s
# Discriminator Cost: 0.5683 (Real: 0.6926 + Fake: 0.4440) Generator Cost: 1.3578
# Epoch 37/100 Time Elapsed: 6.47s
# Discriminator Cost: 0.5712 (Real: 0.6946 + Fake: 0.4477) Generator Cost: 1.3412
# Epoch 38/100 Time Elapsed: 6.25s
# Discriminator Cost: 0.5726 (Real: 0.6961 + Fake: 0.4490) Generator Cost: 1.3309
# Epoch 39/100 Time Elapsed: 6.57s
# Discriminator Cost: 0.5739 (Real: 0.6961 + Fake: 0.4516) Generator Cost: 1.3306
# Epoch 40/100 Time Elapsed: 6.39s
# Discriminator Cost: 0.5743 (Real: 0.6968 + Fake: 0.4518) Generator Cost: 1.3287
# Epoch 41/100 Time Elapsed: 6.46s
# Discriminator Cost: 0.5761 (Real: 0.6991 + Fake: 0.4531) Generator Cost: 1.3209
# Epoch 42/100 Time Elapsed: 6.47s
# Discriminator Cost: 0.5755 (Real: 0.6977 + Fake: 0.4534) Generator Cost: 1.3246
# Epoch 43/100 Time Elapsed: 6.74s
# Discriminator Cost: 0.5773 (Real: 0.6999 + Fake: 0.4546) Generator Cost: 1.3185
# Epoch 44/100 Time Elapsed: 6.48s
# Discriminator Cost: 0.5787 (Real: 0.7002 + Fake: 0.4571) Generator Cost: 1.3143
# Epoch 45/100 Time Elapsed: 6.72s
# Discriminator Cost: 0.5801 (Real: 0.7015 + Fake: 0.4588) Generator Cost: 1.2984
# Epoch 46/100 Time Elapsed: 6.54s
# Discriminator Cost: 0.5788 (Real: 0.7010 + Fake: 0.4565) Generator Cost: 1.3086
# Epoch 47/100 Time Elapsed: 6.45s
# Discriminator Cost: 0.5799 (Real: 0.7011 + Fake: 0.4587) Generator Cost: 1.3048
# Epoch 48/100 Time Elapsed: 6.14s
# Discriminator Cost: 0.5803 (Real: 0.7010 + Fake: 0.4596) Generator Cost: 1.2979
# Epoch 49/100 Time Elapsed: 5.73s
# Discriminator Cost: 0.5814 (Real: 0.7021 + Fake: 0.4607) Generator Cost: 1.2986
# Epoch 50/100 Time Elapsed: 6.60s
# Discriminator Cost: 0.5825 (Real: 0.7038 + Fake: 0.4612) Generator Cost: 1.2890
# Epoch 51/100 Time Elapsed: 6.66s
# Discriminator Cost: 0.5830 (Real: 0.7034 + Fake: 0.4626) Generator Cost: 1.2886
# Epoch 52/100 Time Elapsed: 6.39s
# Discriminator Cost: 0.5817 (Real: 0.7024 + Fake: 0.4611) Generator Cost: 1.2895
# Epoch 53/100 Time Elapsed: 6.36s
# Discriminator Cost: 0.5838 (Real: 0.7036 + Fake: 0.4639) Generator Cost: 1.2807
# Epoch 54/100 Time Elapsed: 6.38s
# Discriminator Cost: 0.5846 (Real: 0.7045 + Fake: 0.4646) Generator Cost: 1.2795
# Epoch 55/100 Time Elapsed: 6.35s
# Discriminator Cost: 0.5846 (Real: 0.7047 + Fake: 0.4644) Generator Cost: 1.2816
# Epoch 56/100 Time Elapsed: 6.48s
# Discriminator Cost: 0.5845 (Real: 0.7043 + Fake: 0.4646) Generator Cost: 1.2796
# Epoch 57/100 Time Elapsed: 6.31s
# Discriminator Cost: 0.5846 (Real: 0.7042 + Fake: 0.4650) Generator Cost: 1.2828
# Epoch 58/100 Time Elapsed: 6.45s
# Discriminator Cost: 0.5869 (Real: 0.7058 + Fake: 0.4680) Generator Cost: 1.2693
# Epoch 59/100 Time Elapsed: 6.71s
# Discriminator Cost: 0.5862 (Real: 0.7050 + Fake: 0.4674) Generator Cost: 1.2758
# Epoch 60/100 Time Elapsed: 6.42s
# Discriminator Cost: 0.5877 (Real: 0.7062 + Fake: 0.4691) Generator Cost: 1.2665
# Epoch 61/100 Time Elapsed: 5.82s
# Discriminator Cost: 0.5883 (Real: 0.7061 + Fake: 0.4705) Generator Cost: 1.2572
# Epoch 62/100 Time Elapsed: 6.90s
# Discriminator Cost: 0.5894 (Real: 0.7085 + Fake: 0.4704) Generator Cost: 1.2529
# Epoch 63/100 Time Elapsed: 6.28s
# Discriminator Cost: 0.5884 (Real: 0.7080 + Fake: 0.4687) Generator Cost: 1.2599
# Epoch 64/100 Time Elapsed: 6.61s
# Discriminator Cost: 0.5904 (Real: 0.7092 + Fake: 0.4716) Generator Cost: 1.2553
# Epoch 65/100 Time Elapsed: 6.48s
# Discriminator Cost: 0.5907 (Real: 0.7086 + Fake: 0.4728) Generator Cost: 1.2509
# Epoch 66/100 Time Elapsed: 6.23s
# Discriminator Cost: 0.5897 (Real: 0.7082 + Fake: 0.4713) Generator Cost: 1.2525
# Epoch 67/100 Time Elapsed: 6.71s
# Discriminator Cost: 0.5890 (Real: 0.7073 + Fake: 0.4708) Generator Cost: 1.2539
# Epoch 68/100 Time Elapsed: 6.57s
# Discriminator Cost: 0.5902 (Real: 0.7084 + Fake: 0.4719) Generator Cost: 1.2516
# Epoch 69/100 Time Elapsed: 6.25s
# Discriminator Cost: 0.5923 (Real: 0.7100 + Fake: 0.4745) Generator Cost: 1.2403
# Epoch 70/100 Time Elapsed: 6.73s
# Discriminator Cost: 0.5916 (Real: 0.7090 + Fake: 0.4742) Generator Cost: 1.2435
# Epoch 71/100 Time Elapsed: 6.17s
# Discriminator Cost: 0.5919 (Real: 0.7097 + Fake: 0.4740) Generator Cost: 1.2430
# Epoch 72/100 Time Elapsed: 6.63s
# Discriminator Cost: 0.5923 (Real: 0.7104 + Fake: 0.4741) Generator Cost: 1.2394
# Epoch 73/100 Time Elapsed: 6.27s
# Discriminator Cost: 0.5942 (Real: 0.7109 + Fake: 0.4776) Generator Cost: 1.2372
# Epoch 74/100 Time Elapsed: 6.47s
# Discriminator Cost: 0.5936 (Real: 0.7104 + Fake: 0.4768) Generator Cost: 1.2329
# Epoch 75/100 Time Elapsed: 6.44s
# Discriminator Cost: 0.5941 (Real: 0.7121 + Fake: 0.4761) Generator Cost: 1.2342
# Epoch 76/100 Time Elapsed: 6.90s
# Discriminator Cost: 0.5943 (Real: 0.7110 + Fake: 0.4775) Generator Cost: 1.2269
# Epoch 77/100 Time Elapsed: 6.63s
# Discriminator Cost: 0.5950 (Real: 0.7120 + Fake: 0.4780) Generator Cost: 1.2280
# Epoch 78/100 Time Elapsed: 6.36s
# Discriminator Cost: 0.5942 (Real: 0.7114 + Fake: 0.4770) Generator Cost: 1.2277
# Epoch 79/100 Time Elapsed: 6.15s
# Discriminator Cost: 0.5952 (Real: 0.7119 + Fake: 0.4785) Generator Cost: 1.2247
# Epoch 80/100 Time Elapsed: 6.42s
# Discriminator Cost: 0.5961 (Real: 0.7125 + Fake: 0.4797) Generator Cost: 1.2245
# Epoch 81/100 Time Elapsed: 6.49s
# Discriminator Cost: 0.5960 (Real: 0.7119 + Fake: 0.4801) Generator Cost: 1.2204
# Epoch 82/100 Time Elapsed: 6.73s
# Discriminator Cost: 0.5963 (Real: 0.7136 + Fake: 0.4790) Generator Cost: 1.2218
# Epoch 83/100 Time Elapsed: 6.65s
# Discriminator Cost: 0.5969 (Real: 0.7134 + Fake: 0.4803) Generator Cost: 1.2207
# Epoch 84/100 Time Elapsed: 5.86s
# Discriminator Cost: 0.5967 (Real: 0.7126 + Fake: 0.4809) Generator Cost: 1.2187
# Epoch 85/100 Time Elapsed: 6.25s
# Discriminator Cost: 0.5982 (Real: 0.7133 + Fake: 0.4830) Generator Cost: 1.2064
# Epoch 86/100 Time Elapsed: 6.15s
# Discriminator Cost: 0.5972 (Real: 0.7136 + Fake: 0.4809) Generator Cost: 1.2155
# Epoch 87/100 Time Elapsed: 6.74s
# Discriminator Cost: 0.5980 (Real: 0.7140 + Fake: 0.4820) Generator Cost: 1.2131
# Epoch 88/100 Time Elapsed: 6.54s
# Discriminator Cost: 0.5994 (Real: 0.7147 + Fake: 0.4840) Generator Cost: 1.2054
# Epoch 89/100 Time Elapsed: 6.46s
# Discriminator Cost: 0.6011 (Real: 0.7164 + Fake: 0.4858) Generator Cost: 1.2006
# Epoch 90/100 Time Elapsed: 6.38s
# Discriminator Cost: 0.6008 (Real: 0.7156 + Fake: 0.4861) Generator Cost: 1.1956
# Epoch 91/100 Time Elapsed: 6.75s
# Discriminator Cost: 0.5988 (Real: 0.7136 + Fake: 0.4840) Generator Cost: 1.2099
# Epoch 92/100 Time Elapsed: 6.53s
# Discriminator Cost: 0.6005 (Real: 0.7148 + Fake: 0.4861) Generator Cost: 1.1973
# Epoch 93/100 Time Elapsed: 6.15s
# Discriminator Cost: 0.5999 (Real: 0.7141 + Fake: 0.4857) Generator Cost: 1.2029
# Epoch 94/100 Time Elapsed: 5.57s
# Discriminator Cost: 0.5999 (Real: 0.7146 + Fake: 0.4851) Generator Cost: 1.2076
# Epoch 95/100 Time Elapsed: 6.50s
# Discriminator Cost: 0.6005 (Real: 0.7153 + Fake: 0.4858) Generator Cost: 1.1982
# Epoch 96/100 Time Elapsed: 6.34s
# Discriminator Cost: 0.6014 (Real: 0.7165 + Fake: 0.4862) Generator Cost: 1.1978
# Epoch 97/100 Time Elapsed: 6.68s
# Discriminator Cost: 0.6004 (Real: 0.7161 + Fake: 0.4847) Generator Cost: 1.1994
# Epoch 98/100 Time Elapsed: 6.51s
# Discriminator Cost: 0.6016 (Real: 0.7167 + Fake: 0.4866) Generator Cost: 1.1881
# Epoch 99/100 Time Elapsed: 6.36s
# Discriminator Cost: 0.6007 (Real: 0.7160 + Fake: 0.4853) Generator Cost: 1.1944
# Epoch 100/100 Time Elapsed: 6.76s
# Discriminator Cost: 0.6024 (Real: 0.7163 + Fake: 0.4884) Generator Cost: 1.1856

# %%
show_graphs(costs_history)

# %%
show_save_samples(sample_images_generated, save=True, gif_frame_duration=0.3)
