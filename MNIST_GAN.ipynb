# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import imageio
import pandas as pd
from tensorflow.examples.tutorials.mnist import input_data
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
"""
Compute the time elapsed
"""
def tic():
    global tic_time
    tic_time = time.time()
    
def toc():
    return time.time() - tic_time

# %%
"""
Load MNIST data
Return: all 70000(train + val + test) images
"""
def load_data():
    mnist = input_data.read_data_sets('MNIST_data/')
    images = np.append(np.append(mnist.train.images, mnist.validation.images, axis=0), mnist.test.images, axis=0)
    return images #shape = (70000, 784)

# %%
"""
Define the Generator
"""
def generator(noises_input, n_1, n_2, n_3, n_out):
    with tf.variable_scope('generator'):
        Z1 = tf.contrib.layers.fully_connected(noises_input, n_1, activation_fn=None, scope='Z1')
        A1 = tf.nn.leaky_relu(Z1, name='A1')
        Z2 = tf.contrib.layers.fully_connected(A1, n_2, activation_fn=None, scope='Z2')
        A2 = tf.nn.leaky_relu(Z2, name='A2')
        Z3 = tf.contrib.layers.fully_connected(A2, n_3, activation_fn=None, scope='Z3')
        A3 = tf.nn.leaky_relu(Z3, name='A3')
        Z_out = tf.contrib.layers.fully_connected(A3, n_out, activation_fn=None, scope='Z_out')
        A_out = tf.nn.tanh(Z_out, name='A_out')
    return A_out

# %%
"""
Define the Discriminator
"""
def discriminator(images_input, n_1, n_2, n_3, n_out, reuse=False):
    with tf.variable_scope('discriminator', reuse=reuse):
        Z1 = tf.contrib.layers.fully_connected(images_input, n_1, activation_fn=None, scope='Z1')
        A1 = tf.nn.leaky_relu(Z1, name='A1')
        A1_dropout = tf.nn.dropout(A1, 0.7, name='A1_dropout')
        Z2 = tf.contrib.layers.fully_connected(A1_dropout, n_2, activation_fn=None, scope='Z2')
        A2 = tf.nn.leaky_relu(Z2, name='A2')
        A2_dropout = tf.nn.dropout(A2, 0.7, name='A2_dropout')
        Z3 = tf.contrib.layers.fully_connected(A2_dropout, n_3, activation_fn=None, scope='Z3')
        A3 = tf.nn.leaky_relu(Z3, name='A3')
        A3_dropout = tf.nn.dropout(A3, 0.7, name='A3_dropout')
        Z_out = tf.contrib.layers.fully_connected(A3_dropout, n_out, activation_fn=None, scope='Z_out')
    return Z_out

# %%
"""
Define and Train Generative Adversarial Networks(GANs) Model
Return: history of costs(both generator and discriminator) 
        samples generated in each epoch
"""
def MNIST_GAN(hyperparams):
    tf.reset_default_graph()
    
    #Load data#
    mnist_images = load_data() * 2 - 1 #shape = (70000, 784)
    
    #Hyperparameters settings and properties#
    noise_size = hyperparams['noise_size']
    batch_size = hyperparams['batch_size']
    label_smooth = hyperparams['label_smooth']
    epoch = hyperparams['epoch']
    generator_n_1 = hyperparams['generator_n_1']
    generator_n_2 = hyperparams['generator_n_2']
    generator_n_3 = hyperparams['generator_n_3']
    generator_n_out = hyperparams['generator_n_out']
    discriminator_n_1 = hyperparams['discriminator_n_1']
    discriminator_n_2 = hyperparams['discriminator_n_2']
    discriminator_n_3 = hyperparams['discriminator_n_3']
    discriminator_n_out = hyperparams['discriminator_n_out']
    gen_learning_rate = hyperparams['gen_learning_rate']
    dis_learning_rate = hyperparams['dis_learning_rate']
    adam_beta1 = hyperparams['adam_beta1']
    sample_size = hyperparams['sample_size']
    data_size = mnist_images.shape[0]
    image_size = mnist_images.shape[1]
    total_batches = np.ceil(data_size / batch_size).astype(np.int32)
    
    #Define placeholders#
    real_images = tf.placeholder(tf.float32, (None, image_size), name='real_images')
    noises_input = tf.placeholder(tf.float32, (None, noise_size), name='noises_input')
    
    #Define the outputs of generator and discriminator#
    fake_images = generator(noises_input, generator_n_1, generator_n_2, generator_n_3, generator_n_out)
    real_logits = discriminator(real_images, discriminator_n_1, discriminator_n_2, discriminator_n_3, discriminator_n_out)
    fake_logits = discriminator(fake_images, discriminator_n_1, discriminator_n_2, discriminator_n_3, discriminator_n_out, reuse=True)
    
    #Define costs of discriminator(fake and real data) and generator#
    dis_real_cost = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=real_logits, labels=tf.multiply(tf.ones_like(real_logits), (1. - label_smooth))))
    dis_fake_cost = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logits, labels=tf.zeros_like(fake_logits)))
    dis_cost = tf.divide(tf.add(dis_real_cost, dis_fake_cost), 2)
    gen_cost = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logits, labels=tf.ones_like(fake_logits)))
    
    #Define the optimization#
    trainable_vars = tf.trainable_variables()
    gen_vars = [var for var in trainable_vars if var.name.startswith('generator')]
    dis_vars = [var for var in trainable_vars if var.name.startswith('discriminator')]
    gen_optimize = tf.train.AdamOptimizer(learning_rate=gen_learning_rate, beta1=adam_beta1, name='gen_optimize').minimize(gen_cost, var_list=gen_vars)
    dis_optimize = tf.train.AdamOptimizer(learning_rate=dis_learning_rate, beta1=adam_beta1, name='dis_optimize').minimize(dis_cost, var_list=dis_vars)
    
    #Training#
    costs_history = {
        'dis_cost_real_iter': [],
        'dis_cost_fake_iter': [],
        'dis_cost_iter': [],
        'gen_cost_iter': []
    }
    sample_images_generated = np.empty((0, sample_size, image_size))
    sample_noises_input = np.random.uniform(low=-1, high=1, size=(sample_size, noise_size))
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(epoch):
            tic()
            
            #Reset the accumulator#
            dis_cost_real_epoch = 0.
            dis_cost_fake_epoch = 0.
            dis_cost_epoch = 0.
            gen_cost_epoch = 0.
            for j in range(total_batches):
                
                #Retrieve the data batch need to be fed#
                index_front = j * batch_size
                index_end = (j + 1) * batch_size if (j + 1) * batch_size < data_size else data_size
                images_batch = mnist_images[index_front:index_end].reshape(-1, image_size)
                noises_batch = np.random.uniform(low=-1, high=1, size=(index_end - index_front, noise_size))
                
                #Update discriminator and generator#
                _, dis_cost_real_iter, dis_cost_fake_iter, dis_cost_iter = sess.run([dis_optimize, dis_real_cost, dis_fake_cost, dis_cost], feed_dict={real_images:images_batch, noises_input:noises_batch})
                _, gen_cost_iter = sess.run([gen_optimize, gen_cost], feed_dict={noises_input:noises_batch})
                
                #Compute and save the average(likely) cost in epoch and in iteration#
                dis_cost_real_epoch += dis_cost_real_iter / data_size
                dis_cost_fake_epoch += dis_cost_fake_iter / data_size
                dis_cost_epoch += dis_cost_iter / data_size
                gen_cost_epoch += gen_cost_iter / data_size
                dis_cost_real_iter /= (index_end - index_front)
                dis_cost_fake_iter /= (index_end - index_front)
                dis_cost_iter /= (index_end - index_front)
                gen_cost_iter /= (index_end - index_front)
                costs_history['dis_cost_real_iter'].append(dis_cost_real_iter)
                costs_history['dis_cost_fake_iter'].append(dis_cost_fake_iter)
                costs_history['dis_cost_iter'].append(dis_cost_iter)
                costs_history['gen_cost_iter'].append(gen_cost_iter)
            
            #Get sample image generated every epoch#
            sample_images_generated_epoch = sess.run(fake_images, feed_dict={noises_input:sample_noises_input}).reshape(1, -1, image_size)
            sample_images_generated = np.append(sample_images_generated, sample_images_generated_epoch, axis=0)
            
            #Print the state every epoch#
            print('Epoch {}/{} Time Elapsed: {:.2f}s'.format(i + 1, epoch, toc()))
            print('Discriminator Cost: {:.4f} (Real: {:.4f} + Fake: {:.4f}) Generator Cost: {:.4f}'.format(dis_cost_epoch, dis_cost_real_epoch, dis_cost_fake_epoch, gen_cost_epoch))
    return costs_history, sample_images_generated

# %%
"""
Show graphs of costs of discriminator and generator
"""
def show_graphs(costs_history, ewma_span=10):
    plt.figure(figsize=(20, 10))
    plt.ylabel('Cost')
    plt.xlabel('Iteration')
    plt.title('Cost - Iteration')
    plt.plot(costs_history['dis_cost_real_iter'], 'b-', alpha=0.3, label='Discriminator Real Cost')
    plt.plot(costs_history['dis_cost_fake_iter'], 'r-', alpha=0.3, label='Discriminator Fake Cost')
    plt.plot(costs_history['dis_cost_iter'], 'g-', alpha=0.3, label='Discriminator Total Cost')
    plt.plot(costs_history['gen_cost_iter'], 'k-', alpha=0.3, label='Generator Cosd')
    ewma_dis_cost_real = pd.stats.moments.ewma(np.array(costs_history['dis_cost_real_iter']), span=ewma_span)
    plt.plot(ewma_dis_cost_real, 'b-', label='Discriminator Real Cost EWMA')
    ewma_dis_cost_fake = pd.stats.moments.ewma(np.array(costs_history['dis_cost_fake_iter']), span=ewma_span)
    plt.plot(ewma_dis_cost_fake, 'r-', label='Discriminator Fake Cost EWMA')
    ewma_dis_cost = pd.stats.moments.ewma(np.array(costs_history['dis_cost_iter']), span=ewma_span)
    plt.plot(ewma_dis_cost, 'g-', label='Discriminator Total Cost EWMA')
    ewma_gen_cost = pd.stats.moments.ewma(np.array(costs_history['gen_cost_iter']), span=ewma_span)
    plt.plot(ewma_gen_cost, 'k-', label='Generator Cost EWMA')
    plt.legend(loc='best')
    plt.show()

# %%
"""
Show and save samples
Variables: 
    sample_images_generated shape: (num of epochs, num of samples in each epoch, num of rows of image, num of column of image)
    save: True if want to save the figures(pngs and gifs)
    folder_name: create the folder if not exists, save figures to the specific folder
"""
def show_save_samples(sample_images_generated, save=False, folder_name='MNIST_GAN_samples', gif_frame_duration=0.25):
    #Scale images to the range of [0, 1]#
    sample_images_generated = (sample_images_generated + 1) / 2
    
    #Create folder if not exists#
    if save and not os.path.exists('./{}'.format(folder_name)):
        os.mkdir(folder_name)
        
    #Parameters#
    epochs = sample_images_generated.shape[0]
    num_sample_each_epoch = sample_images_generated.shape[1]
    
    #Output and save figures#
    for i in range(epochs):
        plt.figure(figsize=(2 * num_sample_each_epoch, 5))
        for j in range(num_sample_each_epoch):
            plt.subplot(1, num_sample_each_epoch, j + 1)
            plt.axis('off')
            plt.imshow(sample_images_generated[i, j].reshape(28, 28), cmap='gray')    
        plt.text(-169, 40, 'Epoch {}'.format(i + 1), fontsize=25) #adjust the text location
        if save:
            plt.savefig('./{}/{}.png'.format(folder_name, i + 1))
        plt.show()
        
    #Make GIF#
    if save:
        gif_frames = []
        for i in range(epochs):
            gif_frames.append(imageio.imread('./{}/{}.png'.format(folder_name, i + 1)))
        imageio.mimsave('./{}/evolution.gif'.format(folder_name), gif_frames, duration=gif_frame_duration)

# %%
"""
Define the hyperparameters
"""
hyperparams={
    'noise_size': 100,
    'batch_size': 128,
    'label_smooth': 0.1,
    'epoch': 100,
    'generator_n_1': 256,
    'generator_n_2': 512,
    'generator_n_3': 1024,
    'generator_n_out': 784,
    'discriminator_n_1': 1024,
    'discriminator_n_2': 512,
    'discriminator_n_3': 256,
    'discriminator_n_out': 1,
    'gen_learning_rate': 0.0001,
    'dis_learning_rate': 0.0001,
    'adam_beta1': 0.5,
    'sample_size': 10
}
costs_history, sample_images_generated = MNIST_GAN(hyperparams)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Epoch 1/100 Time Elapsed: 6.44s
# Discriminator Cost: 0.4642 (Real: 0.4448 + Fake: 0.4837) Generator Cost: 1.4196
# Epoch 2/100 Time Elapsed: 5.67s
# Discriminator Cost: 0.3809 (Real: 0.5283 + Fake: 0.2336) Generator Cost: 2.5234
# Epoch 3/100 Time Elapsed: 6.19s
# Discriminator Cost: 0.3716 (Real: 0.5472 + Fake: 0.1960) Generator Cost: 2.6866
# Epoch 4/100 Time Elapsed: 5.85s
# Discriminator Cost: 0.3580 (Real: 0.5457 + Fake: 0.1703) Generator Cost: 2.6691
# Epoch 5/100 Time Elapsed: 6.00s
# Discriminator Cost: 0.3545 (Real: 0.5458 + Fake: 0.1632) Generator Cost: 2.6940
# Epoch 6/100 Time Elapsed: 6.09s
# Discriminator Cost: 0.3661 (Real: 0.5514 + Fake: 0.1809) Generator Cost: 2.6906
# Epoch 7/100 Time Elapsed: 5.60s
# Discriminator Cost: 0.3793 (Real: 0.5555 + Fake: 0.2031) Generator Cost: 2.7477
# Epoch 8/100 Time Elapsed: 6.29s
# Discriminator Cost: 0.3776 (Real: 0.5502 + Fake: 0.2050) Generator Cost: 2.7488
# Epoch 9/100 Time Elapsed: 6.68s
# Discriminator Cost: 0.3897 (Real: 0.5567 + Fake: 0.2226) Generator Cost: 2.6219
# Epoch 10/100 Time Elapsed: 5.68s
# Discriminator Cost: 0.3968 (Real: 0.5618 + Fake: 0.2318) Generator Cost: 2.5142
# Epoch 11/100 Time Elapsed: 6.08s
# Discriminator Cost: 0.4207 (Real: 0.5855 + Fake: 0.2559) Generator Cost: 2.3565
# Epoch 12/100 Time Elapsed: 6.34s
# Discriminator Cost: 0.4367 (Real: 0.5977 + Fake: 0.2758) Generator Cost: 2.1799
# Epoch 13/100 Time Elapsed: 6.36s
# Discriminator Cost: 0.4594 (Real: 0.6131 + Fake: 0.3057) Generator Cost: 2.0493
# Epoch 14/100 Time Elapsed: 6.52s
# Discriminator Cost: 0.4737 (Real: 0.6239 + Fake: 0.3235) Generator Cost: 1.9213
# Epoch 15/100 Time Elapsed: 6.27s
# Discriminator Cost: 0.4863 (Real: 0.6339 + Fake: 0.3386) Generator Cost: 1.8393
# Epoch 16/100 Time Elapsed: 6.72s
# Discriminator Cost: 0.5077 (Real: 0.6494 + Fake: 0.3661) Generator Cost: 1.6998
# Epoch 17/100 Time Elapsed: 6.36s
# Discriminator Cost: 0.5143 (Real: 0.6544 + Fake: 0.3742) Generator Cost: 1.6585
# Epoch 18/100 Time Elapsed: 6.68s
# Discriminator Cost: 0.5198 (Real: 0.6574 + Fake: 0.3821) Generator Cost: 1.6203
# Epoch 19/100 Time Elapsed: 6.21s
# Discriminator Cost: 0.5235 (Real: 0.6604 + Fake: 0.3866) Generator Cost: 1.5951
# Epoch 20/100 Time Elapsed: 6.46s
# Discriminator Cost: 0.5240 (Real: 0.6612 + Fake: 0.3869) Generator Cost: 1.5834
# Epoch 21/100 Time Elapsed: 6.37s
# Discriminator Cost: 0.5288 (Real: 0.6643 + Fake: 0.3932) Generator Cost: 1.5611
# Epoch 22/100 Time Elapsed: 6.59s
# Discriminator Cost: 0.5299 (Real: 0.6659 + Fake: 0.3939) Generator Cost: 1.5665
# Epoch 23/100 Time Elapsed: 6.41s
# Discriminator Cost: 0.5298 (Real: 0.6661 + Fake: 0.3935) Generator Cost: 1.5578
# Epoch 24/100 Time Elapsed: 6.64s
# Discriminator Cost: 0.5374 (Real: 0.6714 + Fake: 0.4033) Generator Cost: 1.5174
# Epoch 25/100 Time Elapsed: 6.62s
# Discriminator Cost: 0.5377 (Real: 0.6714 + Fake: 0.4039) Generator Cost: 1.5058
# Epoch 26/100 Time Elapsed: 6.50s
# Discriminator Cost: 0.5400 (Real: 0.6727 + Fake: 0.4074) Generator Cost: 1.4957
# Epoch 27/100 Time Elapsed: 6.53s
# Discriminator Cost: 0.5427 (Real: 0.6754 + Fake: 0.4099) Generator Cost: 1.4821
# Epoch 28/100 Time Elapsed: 6.82s
# Discriminator Cost: 0.5460 (Real: 0.6786 + Fake: 0.4134) Generator Cost: 1.4739
# Epoch 29/100 Time Elapsed: 6.24s
# Discriminator Cost: 0.5475 (Real: 0.6781 + Fake: 0.4169) Generator Cost: 1.4576
# Epoch 30/100 Time Elapsed: 6.58s
# Discriminator Cost: 0.5527 (Real: 0.6821 + Fake: 0.4233) Generator Cost: 1.4393
# Epoch 31/100 Time Elapsed: 5.90s
# Discriminator Cost: 0.5526 (Real: 0.6817 + Fake: 0.4234) Generator Cost: 1.4434
# Epoch 32/100 Time Elapsed: 5.90s
# Discriminator Cost: 0.5576 (Real: 0.6856 + Fake: 0.4296) Generator Cost: 1.4218
# Epoch 33/100 Time Elapsed: 6.07s
# Discriminator Cost: 0.5600 (Real: 0.6871 + Fake: 0.4329) Generator Cost: 1.3980
# Epoch 34/100 Time Elapsed: 6.63s
# Discriminator Cost: 0.5622 (Real: 0.6881 + Fake: 0.4362) Generator Cost: 1.3947
# Epoch 35/100 Time Elapsed: 6.51s
# Discriminator Cost: 0.5639 (Real: 0.6889 + Fake: 0.4389) Generator Cost: 1.3818
# Epoch 36/100 Time Elapsed: 6.74s
# Discriminator Cost: 0.5655 (Real: 0.6914 + Fake: 0.4396) Generator Cost: 1.3766
# Epoch 37/100 Time Elapsed: 6.63s
# Discriminator Cost: 0.5699 (Real: 0.6943 + Fake: 0.4456) Generator Cost: 1.3555
# Epoch 38/100 Time Elapsed: 6.73s
# Discriminator Cost: 0.5694 (Real: 0.6934 + Fake: 0.4454) Generator Cost: 1.3577
# Epoch 39/100 Time Elapsed: 6.44s
# Discriminator Cost: 0.5718 (Real: 0.6951 + Fake: 0.4485) Generator Cost: 1.3438
# Epoch 40/100 Time Elapsed: 5.47s
# Discriminator Cost: 0.5719 (Real: 0.6950 + Fake: 0.4487) Generator Cost: 1.3491
# Epoch 41/100 Time Elapsed: 5.69s
# Discriminator Cost: 0.5735 (Real: 0.6966 + Fake: 0.4504) Generator Cost: 1.3383
# Epoch 42/100 Time Elapsed: 6.16s
# Discriminator Cost: 0.5730 (Real: 0.6959 + Fake: 0.4500) Generator Cost: 1.3421
# Epoch 43/100 Time Elapsed: 5.78s
# Discriminator Cost: 0.5748 (Real: 0.6970 + Fake: 0.4527) Generator Cost: 1.3336
# Epoch 44/100 Time Elapsed: 5.80s
# Discriminator Cost: 0.5737 (Real: 0.6964 + Fake: 0.4509) Generator Cost: 1.3406
# Epoch 45/100 Time Elapsed: 5.96s
# Discriminator Cost: 0.5746 (Real: 0.6969 + Fake: 0.4524) Generator Cost: 1.3267
# Epoch 46/100 Time Elapsed: 6.32s
# Discriminator Cost: 0.5776 (Real: 0.7001 + Fake: 0.4552) Generator Cost: 1.3238
# Epoch 47/100 Time Elapsed: 6.39s
# Discriminator Cost: 0.5779 (Real: 0.6989 + Fake: 0.4569) Generator Cost: 1.3144
# Epoch 48/100 Time Elapsed: 6.13s
# Discriminator Cost: 0.5779 (Real: 0.7005 + Fake: 0.4554) Generator Cost: 1.3160
# Epoch 49/100 Time Elapsed: 6.08s
# Discriminator Cost: 0.5795 (Real: 0.7015 + Fake: 0.4575) Generator Cost: 1.3059
# Epoch 50/100 Time Elapsed: 6.29s
# Discriminator Cost: 0.5797 (Real: 0.7019 + Fake: 0.4575) Generator Cost: 1.3067
# Epoch 51/100 Time Elapsed: 6.11s
# Discriminator Cost: 0.5809 (Real: 0.7022 + Fake: 0.4595) Generator Cost: 1.2959
# Epoch 52/100 Time Elapsed: 6.30s
# Discriminator Cost: 0.5806 (Real: 0.7023 + Fake: 0.4589) Generator Cost: 1.2955
# Epoch 53/100 Time Elapsed: 6.50s
# Discriminator Cost: 0.5795 (Real: 0.7013 + Fake: 0.4576) Generator Cost: 1.3014
# Epoch 54/100 Time Elapsed: 6.63s
# Discriminator Cost: 0.5810 (Real: 0.7022 + Fake: 0.4599) Generator Cost: 1.3016
# Epoch 55/100 Time Elapsed: 6.64s
# Discriminator Cost: 0.5816 (Real: 0.7025 + Fake: 0.4607) Generator Cost: 1.2940
# Epoch 56/100 Time Elapsed: 6.60s
# Discriminator Cost: 0.5832 (Real: 0.7044 + Fake: 0.4619) Generator Cost: 1.2833
# Epoch 57/100 Time Elapsed: 6.79s
# Discriminator Cost: 0.5827 (Real: 0.7034 + Fake: 0.4621) Generator Cost: 1.2931
# Epoch 58/100 Time Elapsed: 6.36s
# Discriminator Cost: 0.5828 (Real: 0.7036 + Fake: 0.4621) Generator Cost: 1.2877
# Epoch 59/100 Time Elapsed: 6.55s
# Discriminator Cost: 0.5830 (Real: 0.7038 + Fake: 0.4622) Generator Cost: 1.2798
# Epoch 60/100 Time Elapsed: 6.46s
# Discriminator Cost: 0.5835 (Real: 0.7045 + Fake: 0.4626) Generator Cost: 1.2924
# Epoch 61/100 Time Elapsed: 6.81s
# Discriminator Cost: 0.5833 (Real: 0.7031 + Fake: 0.4635) Generator Cost: 1.2803
# Epoch 62/100 Time Elapsed: 6.44s
# Discriminator Cost: 0.5862 (Real: 0.7063 + Fake: 0.4661) Generator Cost: 1.2722
# Epoch 63/100 Time Elapsed: 6.43s
# Discriminator Cost: 0.5864 (Real: 0.7061 + Fake: 0.4667) Generator Cost: 1.2672
# Epoch 64/100 Time Elapsed: 6.21s
# Discriminator Cost: 0.5865 (Real: 0.7059 + Fake: 0.4672) Generator Cost: 1.2673
# Epoch 65/100 Time Elapsed: 6.47s
# Discriminator Cost: 0.5859 (Real: 0.7061 + Fake: 0.4657) Generator Cost: 1.2702
# Epoch 66/100 Time Elapsed: 6.40s
# Discriminator Cost: 0.5875 (Real: 0.7060 + Fake: 0.4690) Generator Cost: 1.2606
# Epoch 67/100 Time Elapsed: 6.62s
# Discriminator Cost: 0.5891 (Real: 0.7086 + Fake: 0.4697) Generator Cost: 1.2522
# Epoch 68/100 Time Elapsed: 6.72s
# Discriminator Cost: 0.5879 (Real: 0.7072 + Fake: 0.4687) Generator Cost: 1.2529
# Epoch 69/100 Time Elapsed: 6.49s
# Discriminator Cost: 0.5886 (Real: 0.7075 + Fake: 0.4697) Generator Cost: 1.2606
# Epoch 70/100 Time Elapsed: 6.54s
# Discriminator Cost: 0.5898 (Real: 0.7084 + Fake: 0.4711) Generator Cost: 1.2553
# Epoch 71/100 Time Elapsed: 6.59s
# Discriminator Cost: 0.5909 (Real: 0.7096 + Fake: 0.4722) Generator Cost: 1.2497
# Epoch 72/100 Time Elapsed: 6.36s
# Discriminator Cost: 0.5892 (Real: 0.7081 + Fake: 0.4703) Generator Cost: 1.2498
# Epoch 73/100 Time Elapsed: 5.94s
# Discriminator Cost: 0.5899 (Real: 0.7098 + Fake: 0.4700) Generator Cost: 1.2549
# Epoch 74/100 Time Elapsed: 6.81s
# Discriminator Cost: 0.5907 (Real: 0.7094 + Fake: 0.4720) Generator Cost: 1.2457
# Epoch 75/100 Time Elapsed: 6.42s
# Discriminator Cost: 0.5908 (Real: 0.7093 + Fake: 0.4722) Generator Cost: 1.2489
# Epoch 76/100 Time Elapsed: 6.30s
# Discriminator Cost: 0.5914 (Real: 0.7095 + Fake: 0.4734) Generator Cost: 1.2413
# Epoch 77/100 Time Elapsed: 6.27s
# Discriminator Cost: 0.5901 (Real: 0.7090 + Fake: 0.4712) Generator Cost: 1.2462
# Epoch 78/100 Time Elapsed: 6.30s
# Discriminator Cost: 0.5927 (Real: 0.7113 + Fake: 0.4741) Generator Cost: 1.2355
# Epoch 79/100 Time Elapsed: 6.42s
# Discriminator Cost: 0.5912 (Real: 0.7099 + Fake: 0.4724) Generator Cost: 1.2387
# Epoch 80/100 Time Elapsed: 6.41s
# Discriminator Cost: 0.5932 (Real: 0.7112 + Fake: 0.4751) Generator Cost: 1.2321
# Epoch 81/100 Time Elapsed: 6.46s
# Discriminator Cost: 0.5925 (Real: 0.7105 + Fake: 0.4746) Generator Cost: 1.2359
# Epoch 82/100 Time Elapsed: 6.65s
# Discriminator Cost: 0.5924 (Real: 0.7104 + Fake: 0.4744) Generator Cost: 1.2359
# Epoch 83/100 Time Elapsed: 6.58s
# Discriminator Cost: 0.5953 (Real: 0.7137 + Fake: 0.4769) Generator Cost: 1.2284
# Epoch 84/100 Time Elapsed: 6.09s
# Discriminator Cost: 0.5936 (Real: 0.7124 + Fake: 0.4747) Generator Cost: 1.2339
# Epoch 85/100 Time Elapsed: 6.60s
# Discriminator Cost: 0.5948 (Real: 0.7122 + Fake: 0.4774) Generator Cost: 1.2255
# Epoch 86/100 Time Elapsed: 6.53s
# Discriminator Cost: 0.5932 (Real: 0.7109 + Fake: 0.4754) Generator Cost: 1.2243
# Epoch 87/100 Time Elapsed: 6.28s
# Discriminator Cost: 0.5956 (Real: 0.7130 + Fake: 0.4782) Generator Cost: 1.2225
# Epoch 88/100 Time Elapsed: 6.49s
# Discriminator Cost: 0.5969 (Real: 0.7142 + Fake: 0.4797) Generator Cost: 1.2136
# Epoch 89/100 Time Elapsed: 6.48s
# Discriminator Cost: 0.5975 (Real: 0.7143 + Fake: 0.4808) Generator Cost: 1.2091
# Epoch 90/100 Time Elapsed: 6.38s
# Discriminator Cost: 0.5961 (Real: 0.7129 + Fake: 0.4793) Generator Cost: 1.2186
# Epoch 91/100 Time Elapsed: 6.32s
# Discriminator Cost: 0.5977 (Real: 0.7145 + Fake: 0.4808) Generator Cost: 1.2085
# Epoch 92/100 Time Elapsed: 5.33s
# Discriminator Cost: 0.5978 (Real: 0.7151 + Fake: 0.4806) Generator Cost: 1.2081
# Epoch 93/100 Time Elapsed: 6.18s
# Discriminator Cost: 0.5973 (Real: 0.7147 + Fake: 0.4798) Generator Cost: 1.2104
# Epoch 94/100 Time Elapsed: 6.34s
# Discriminator Cost: 0.5976 (Real: 0.7136 + Fake: 0.4815) Generator Cost: 1.2129
# Epoch 95/100 Time Elapsed: 6.07s
# Discriminator Cost: 0.5988 (Real: 0.7153 + Fake: 0.4823) Generator Cost: 1.2066
# Epoch 96/100 Time Elapsed: 6.38s
# Discriminator Cost: 0.5974 (Real: 0.7133 + Fake: 0.4815) Generator Cost: 1.2062
# Epoch 97/100 Time Elapsed: 5.83s
# Discriminator Cost: 0.5987 (Real: 0.7149 + Fake: 0.4824) Generator Cost: 1.2069
# Epoch 98/100 Time Elapsed: 6.40s
# Discriminator Cost: 0.5985 (Real: 0.7152 + Fake: 0.4819) Generator Cost: 1.2031
# Epoch 99/100 Time Elapsed: 6.29s
# Discriminator Cost: 0.6003 (Real: 0.7165 + Fake: 0.4841) Generator Cost: 1.1954
# Epoch 100/100 Time Elapsed: 6.53s
# Discriminator Cost: 0.5982 (Real: 0.7149 + Fake: 0.4816) Generator Cost: 1.2055

# %%
show_graphs(costs_history)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:13: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   del sys.path[0]
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:15: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:17: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:19: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version

# %%
show_save_samples(sample_images_generated, save=True, gif_frame_duration=0.3)
